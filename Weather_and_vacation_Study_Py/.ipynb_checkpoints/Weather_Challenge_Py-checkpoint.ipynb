# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#Running initial example first to find location for each parameter
main_url = "http://api.openweathermap.org/data/2.5/weather?"
url = f"{main_url}appid={weather_api_key}&q="
city = "Melbourne"
response = requests.get(url + city)
responce_json = response.json()
print(json.dumps(responce_json, indent=4, sort_keys=True))

city_lat = responce_json["coord"]["lat"]
print(city_lat)
city_lng = responce_json["coord"]["lon"]
print(city_lng)
city_max_temp = responce_json["main"]["temp_max"]
print(city_max_temp)
city_humidity = responce_json["main"]["humidity"]
print (city_humidity)
city_clouds = responce_json["clouds"]["all"]
print(city_clouds)
city_wind = responce_json["wind"]["speed"]
print(city_wind)
city_country = responce_json["sys"]["country"]
print(city_country)
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.0836,
#         "lon": -80.6081
#     },
#     "dt": 1690013303,
#     "id": 4163971,
#     "main": {
#         "feels_like": 299.88,
#         "humidity": 85,
#         "pressure": 1014,
#         "temp": 299.02,
#         "temp_max": 300.91,
#         "temp_min": 297.05
#     },
#     "name": "Melbourne",
#     "sys": {
#         "country": "US",
#         "id": 2007578,
#         "sunrise": 1690022345,
#         "sunset": 1690071499,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 290,
#         "speed": 5.14
#     }
# }
# 28.0836
# -80.6081
# 300.91
# 85
# 0
# 5.14
# US

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
main_url = "http://api.openweathermap.org/data/2.5/weather?"
#declaring units as metrics
units = "metric"
#url
url = f"{main_url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
today = datetime.today().strftime('%d-%m-%Y')

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    response = requests.get(city_url)
    #print(json.dumps(response_json, indent=4, sort_keys=True))
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #print(json.dumps(city_weather, indent=4, sort_keys=True))

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        #print(city_lat)
        city_lng = city_weather["coord"]["lon"]
        #print(city_lng)
        city_max_temp = city_weather["main"]["temp_max"]
        #print(city_max_temp)
        city_humidity = city_weather["main"]["humidity"]
        #print (city_humidity)
        city_clouds = city_weather["clouds"]["all"]
        #print(city_clouds)
        city_wind = city_weather["wind"]["speed"]
        #print(city_wind)
        city_country = city_weather["sys"]["country"]
        #print(city_country)
        city_date = today

        #Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nadi
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | edinburgh of the seven seas
# Processing Record 5 of Set 1 | vila velha
# Processing Record 6 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | santa elena de uairen
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | uturoa
# Processing Record 11 of Set 1 | papatowai
# Processing Record 12 of Set 1 | badger
# Processing Record 13 of Set 1 | zhangatas
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | margaret river
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | saipan
# Processing Record 18 of Set 1 | fale old settlement
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | labrador city
# Processing Record 22 of Set 1 | pathein
# Processing Record 23 of Set 1 | trincomalee
# Processing Record 24 of Set 1 | epe
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | keflavik
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | jiuquan
# Processing Record 31 of Set 1 | college
# Processing Record 32 of Set 1 | hadibu
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | armacao de buzios
# Processing Record 36 of Set 1 | utrik
# Processing Record 37 of Set 1 | loreto
# Processing Record 38 of Set 1 | al ghayzah
# Processing Record 39 of Set 1 | seven pagodas
# Processing Record 40 of Set 1 | baturite
# Processing Record 41 of Set 1 | constantia
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | grytviken
# Processing Record 44 of Set 1 | cao bang
# Processing Record 45 of Set 1 | akhmim
# Processing Record 46 of Set 1 | arzgir
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | itoman
# Processing Record 49 of Set 1 | rio grande
# Processing Record 50 of Set 1 | whitehorse
# Processing Record 0 of Set 2 | marica
# Processing Record 1 of Set 2 | mancio lima
# Processing Record 2 of Set 2 | safi
# Processing Record 3 of Set 2 | dolores
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | kingston
# Processing Record 8 of Set 2 | huanren
# Processing Record 9 of Set 2 | port mathurin
# Processing Record 10 of Set 2 | san martin de los andes
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | sahibganj
# Processing Record 14 of Set 2 | tura
# Processing Record 15 of Set 2 | saddle brooke
# City not found. Skipping...
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | invercargill
# Processing Record 18 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 2 | cairns city
# City not found. Skipping...
# Processing Record 20 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | dzilam gonzalez
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | morshansk
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | karaton
# Processing Record 27 of Set 2 | ha'il
# Processing Record 28 of Set 2 | alaghsas
# Processing Record 29 of Set 2 | raja
# Processing Record 30 of Set 2 | lamu
# Processing Record 31 of Set 2 | cable beach
# City not found. Skipping...
# Processing Record 32 of Set 2 | dwarka
# Processing Record 33 of Set 2 | devinuwara
# City not found. Skipping...
# Processing Record 34 of Set 2 | atafu village
# Processing Record 35 of Set 2 | nastola
# Processing Record 36 of Set 2 | olonkinbyen
# Processing Record 37 of Set 2 | lazaro cardenas
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | caras
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | corozal
# Processing Record 42 of Set 2 | buncrana
# Processing Record 43 of Set 2 | ciudad guayana
# Processing Record 44 of Set 2 | blackmans bay
# Processing Record 45 of Set 2 | tabuk
# Processing Record 46 of Set 2 | hohhot
# Processing Record 47 of Set 2 | singkil
# Processing Record 48 of Set 2 | minas de marcona
# Processing Record 49 of Set 2 | tindouf
# Processing Record 0 of Set 3 | zhenlai
# Processing Record 1 of Set 3 | egilsstadir
# Processing Record 2 of Set 3 | bilibino
# Processing Record 3 of Set 3 | arauco
# Processing Record 4 of Set 3 | marsa alam
# Processing Record 5 of Set 3 | punta arenas
# Processing Record 6 of Set 3 | ekibastuz
# Processing Record 7 of Set 3 | haiku-pauwela
# Processing Record 8 of Set 3 | afaahiti
# Processing Record 9 of Set 3 | revda
# Processing Record 10 of Set 3 | piti village
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | sawai madhopur
# Processing Record 13 of Set 3 | godalming
# Processing Record 14 of Set 3 | vorgashor
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | salalah
# Processing Record 17 of Set 3 | udachny
# Processing Record 18 of Set 3 | savsjo
# City not found. Skipping...
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | tlacotalpan
# Processing Record 21 of Set 3 | golyshmanovo
# Processing Record 22 of Set 3 | nar'yan-mar
# Processing Record 23 of Set 3 | liverdun
# Processing Record 24 of Set 3 | sampacho
# Processing Record 25 of Set 3 | seminole
# Processing Record 26 of Set 3 | general salgado
# Processing Record 27 of Set 3 | kill devil hills
# Processing Record 28 of Set 3 | mukalla
# Processing Record 29 of Set 3 | nanao
# Processing Record 30 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 31 of Set 3 | mikun'
# Processing Record 32 of Set 3 | lae
# Processing Record 33 of Set 3 | mount pearl
# Processing Record 34 of Set 3 | west island
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | ha giang
# Processing Record 37 of Set 3 | kohlu
# Processing Record 38 of Set 3 | moab
# Processing Record 39 of Set 3 | faya-largeau
# Processing Record 40 of Set 3 | hawaiian paradise park
# Processing Record 41 of Set 3 | polyarnyy
# Processing Record 42 of Set 3 | colonia
# Processing Record 43 of Set 3 | tuy hoa
# Processing Record 44 of Set 3 | tidjikja
# Processing Record 45 of Set 3 | daru
# Processing Record 46 of Set 3 | yuzhno-kurilsk
# Processing Record 47 of Set 3 | st. john's
# Processing Record 48 of Set 3 | merowe
# Processing Record 49 of Set 3 | aasiaat
# Processing Record 0 of Set 4 | bayan nur
# City not found. Skipping...
# Processing Record 1 of Set 4 | tonota
# Processing Record 2 of Set 4 | levuka
# Processing Record 3 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 4 of Set 4 | kaiapoi
# Processing Record 5 of Set 4 | kangding
# Processing Record 6 of Set 4 | la'ie
# Processing Record 7 of Set 4 | bandarbeyla
# Processing Record 8 of Set 4 | lihue
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | dryden
# Processing Record 12 of Set 4 | saint-pierre
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | tazovsky
# Processing Record 16 of Set 4 | nemuro
# Processing Record 17 of Set 4 | villa gesell
# Processing Record 18 of Set 4 | goundam
# Processing Record 19 of Set 4 | uliastay
# Processing Record 20 of Set 4 | tabou
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | queenstown
# Processing Record 23 of Set 4 | anadyr
# Processing Record 24 of Set 4 | linxia chengguanzhen
# Processing Record 25 of Set 4 | flying fish cove
# Processing Record 26 of Set 4 | renk
# City not found. Skipping...
# Processing Record 27 of Set 4 | labytnangi
# Processing Record 28 of Set 4 | christchurch
# Processing Record 29 of Set 4 | bria
# Processing Record 30 of Set 4 | chinde
# Processing Record 31 of Set 4 | ust'-barguzin
# Processing Record 32 of Set 4 | kapa'a
# Processing Record 33 of Set 4 | dudinka
# Processing Record 34 of Set 4 | fomboni
# Processing Record 35 of Set 4 | wewak
# Processing Record 36 of Set 4 | tazacorte
# Processing Record 37 of Set 4 | avarua
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | nuuk
# Processing Record 40 of Set 4 | jorpeland
# Processing Record 41 of Set 4 | aripuana
# Processing Record 42 of Set 4 | san antonio de pale
# Processing Record 43 of Set 4 | yigo village
# Processing Record 44 of Set 4 | estevan
# Processing Record 45 of Set 4 | matoury
# Processing Record 46 of Set 4 | alpine
# Processing Record 47 of Set 4 | thunder bay
# Processing Record 48 of Set 4 | reserva
# Processing Record 49 of Set 4 | dakhla
# Processing Record 0 of Set 5 | yarmouth
# Processing Record 1 of Set 5 | phang nga
# Processing Record 2 of Set 5 | kuanda
# Processing Record 3 of Set 5 | fort bragg
# Processing Record 4 of Set 5 | aluksne
# Processing Record 5 of Set 5 | forrest city
# Processing Record 6 of Set 5 | colby
# Processing Record 7 of Set 5 | bontang
# Processing Record 8 of Set 5 | quellon
# Processing Record 9 of Set 5 | port saint john's
# Processing Record 10 of Set 5 | radomsko
# Processing Record 11 of Set 5 | maloye ganyushkino
# Processing Record 12 of Set 5 | mossel bay
# Processing Record 13 of Set 5 | dobrich
# Processing Record 14 of Set 5 | mpika
# Processing Record 15 of Set 5 | floro
# Processing Record 16 of Set 5 | new norfolk
# Processing Record 17 of Set 5 | isafjordur
# Processing Record 18 of Set 5 | novodvinsk
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | selfoss
# Processing Record 21 of Set 5 | bryne
# Processing Record 22 of Set 5 | inhambane
# Processing Record 23 of Set 5 | cole harbour
# Processing Record 24 of Set 5 | brookings
# Processing Record 25 of Set 5 | monrovia
# Processing Record 26 of Set 5 | prudhoe
# Processing Record 27 of Set 5 | saint-paul
# Processing Record 28 of Set 5 | mabaruma
# Processing Record 29 of Set 5 | roxas
# Processing Record 30 of Set 5 | n'zeto
# Processing Record 31 of Set 5 | cruzeiro do sul
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | kasane
# Processing Record 34 of Set 5 | belmonte
# Processing Record 35 of Set 5 | jerada
# Processing Record 36 of Set 5 | tommot
# Processing Record 37 of Set 5 | acarau
# Processing Record 38 of Set 5 | saint-andre
# Processing Record 39 of Set 5 | merizo village
# Processing Record 40 of Set 5 | ghadamis
# Processing Record 41 of Set 5 | birjand
# Processing Record 42 of Set 5 | telica
# Processing Record 43 of Set 5 | jinghong
# Processing Record 44 of Set 5 | puerto armuelles
# Processing Record 45 of Set 5 | kirensk
# Processing Record 46 of Set 5 | nikolayevsk-on-amure
# Processing Record 47 of Set 5 | gadzhiyevo
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | suntar
# Processing Record 0 of Set 6 | saint-pol-sur-mer
# Processing Record 1 of Set 6 | flin flon
# Processing Record 2 of Set 6 | qamdo
# Processing Record 3 of Set 6 | jinchang
# Processing Record 4 of Set 6 | remire-montjoly
# Processing Record 5 of Set 6 | mirny
# Processing Record 6 of Set 6 | bandar-e lengeh
# Processing Record 7 of Set 6 | purcell
# Processing Record 8 of Set 6 | tsiombe
# Processing Record 9 of Set 6 | la passe
# Processing Record 10 of Set 6 | vadso
# Processing Record 11 of Set 6 | port lincoln
# Processing Record 12 of Set 6 | reggane
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | vilyuchinsk
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | sumbe
# Processing Record 17 of Set 6 | vila franca do campo
# Processing Record 18 of Set 6 | ippy
# Processing Record 19 of Set 6 | bardai
# Processing Record 20 of Set 6 | mana
# Processing Record 21 of Set 6 | padang
# Processing Record 22 of Set 6 | shimoda
# Processing Record 23 of Set 6 | cinisi
# Processing Record 24 of Set 6 | ust-nera
# Processing Record 25 of Set 6 | svetlyy
# Processing Record 26 of Set 6 | praia da vitoria
# Processing Record 27 of Set 6 | tchibanga
# Processing Record 28 of Set 6 | talara
# Processing Record 29 of Set 6 | kristiansund
# Processing Record 30 of Set 6 | viqueque
# Processing Record 31 of Set 6 | sandnessjoen
# Processing Record 32 of Set 6 | port alfred
# Processing Record 33 of Set 6 | compostela
# Processing Record 34 of Set 6 | maria aurora
# Processing Record 35 of Set 6 | bubaque
# Processing Record 36 of Set 6 | ostersund
# Processing Record 37 of Set 6 | pisco
# Processing Record 38 of Set 6 | parras de la fuente
# Processing Record 39 of Set 6 | vilyuysk
# Processing Record 40 of Set 6 | jining
# Processing Record 41 of Set 6 | amahai
# Processing Record 42 of Set 6 | alesund
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | mumbwa
# Processing Record 45 of Set 6 | carnarvon
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | deniliquin
# Processing Record 48 of Set 6 | montrose
# Processing Record 49 of Set 6 | mingguang
# Processing Record 0 of Set 7 | puerto baquerizo moreno
# Processing Record 1 of Set 7 | kerema
# Processing Record 2 of Set 7 | rosso
# Processing Record 3 of Set 7 | tadine
# Processing Record 4 of Set 7 | pangai
# Processing Record 5 of Set 7 | pionerskiy
# Processing Record 6 of Set 7 | la sarre
# Processing Record 7 of Set 7 | sosnovo-ozerskoye
# Processing Record 8 of Set 7 | ancud
# Processing Record 9 of Set 7 | wailua homesteads
# Processing Record 10 of Set 7 | stanley
# Processing Record 11 of Set 7 | nova zagora
# Processing Record 12 of Set 7 | novyy urengoy
# Processing Record 13 of Set 7 | mar del plata
# Processing Record 14 of Set 7 | nova sintra
# Processing Record 15 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 16 of Set 7 | saint-dizier
# Processing Record 17 of Set 7 | szekszard
# Processing Record 18 of Set 7 | sibut
# Processing Record 19 of Set 7 | batangafo
# Processing Record 20 of Set 7 | qui nhon
# Processing Record 21 of Set 7 | manta
# Processing Record 22 of Set 7 | kadom
# Processing Record 23 of Set 7 | massawa
# Processing Record 24 of Set 7 | selty
# Processing Record 25 of Set 7 | howrah
# Processing Record 26 of Set 7 | saguenay
# Processing Record 27 of Set 7 | juba
# Processing Record 28 of Set 7 | mahibadhoo
# Processing Record 29 of Set 7 | palikir - national government center
# Processing Record 30 of Set 7 | natividade
# Processing Record 31 of Set 7 | vail
# Processing Record 32 of Set 7 | ulladulla
# Processing Record 33 of Set 7 | almenara
# Processing Record 34 of Set 7 | tromso
# Processing Record 35 of Set 7 | ilhabela
# Processing Record 36 of Set 7 | ceres
# Processing Record 37 of Set 7 | sisimiut
# Processing Record 38 of Set 7 | klyuchi
# Processing Record 39 of Set 7 | rongelap
# Processing Record 40 of Set 7 | rawicz
# Processing Record 41 of Set 7 | puerto lempira
# Processing Record 42 of Set 7 | jertih
# Processing Record 43 of Set 7 | manacapuru
# Processing Record 44 of Set 7 | chui
# Processing Record 45 of Set 7 | maclovio rojas
# City not found. Skipping...
# Processing Record 46 of Set 7 | hirara
# Processing Record 47 of Set 7 | ambovombe
# Processing Record 48 of Set 7 | kavieng
# Processing Record 49 of Set 7 | naze
# Processing Record 0 of Set 8 | jiazi
# Processing Record 1 of Set 8 | tamanrasset
# Processing Record 2 of Set 8 | carinhanha
# Processing Record 3 of Set 8 | portland
# Processing Record 4 of Set 8 | okhotsk
# Processing Record 5 of Set 8 | suamico
# Processing Record 6 of Set 8 | midvagur
# Processing Record 7 of Set 8 | francisco sa
# Processing Record 8 of Set 8 | galich
# Processing Record 9 of Set 8 | kununurra
# Processing Record 10 of Set 8 | chibougamau
# Processing Record 11 of Set 8 | santa cruz
# Processing Record 12 of Set 8 | sambhal
# Processing Record 13 of Set 8 | adoru
# Processing Record 14 of Set 8 | kodok
# City not found. Skipping...
# Processing Record 15 of Set 8 | soe
# Processing Record 16 of Set 8 | tafuna
# Processing Record 17 of Set 8 | coquimbo
# Processing Record 18 of Set 8 | kapuskasing
# Processing Record 19 of Set 8 | kachug
# Processing Record 20 of Set 8 | cabo san lucas
# Processing Record 21 of Set 8 | kisangani
# Processing Record 22 of Set 8 | kailua-kona
# Processing Record 23 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 24 of Set 8 | juli
# Processing Record 25 of Set 8 | seogwipo
# City not found. Skipping...
# Processing Record 26 of Set 8 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 27 of Set 8 | biankouma
# Processing Record 28 of Set 8 | ilabaya
# Processing Record 29 of Set 8 | cambria
# Processing Record 30 of Set 8 | gizo
# Processing Record 31 of Set 8 | suva
# Processing Record 32 of Set 8 | timbuktu
# Processing Record 33 of Set 8 | bamboo flat
# Processing Record 34 of Set 8 | vernon
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | basse-terre
# Processing Record 37 of Set 8 | kendari
# Processing Record 38 of Set 8 | sabang
# Processing Record 39 of Set 8 | grand falls-windsor
# Processing Record 40 of Set 8 | nookat
# City not found. Skipping...
# Processing Record 41 of Set 8 | romny
# Processing Record 42 of Set 8 | nabire
# Processing Record 43 of Set 8 | ilulissat
# Processing Record 44 of Set 8 | antsiranana
# Processing Record 45 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 46 of Set 8 | prince rupert
# Processing Record 47 of Set 8 | medgidia
# Processing Record 48 of Set 8 | nguigmi
# Processing Record 49 of Set 8 | tolanaro
# Processing Record 0 of Set 9 | myitkyina
# Processing Record 1 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 9 | mata-utu
# Processing Record 3 of Set 9 | dundalk
# Processing Record 4 of Set 9 | ambon
# Processing Record 5 of Set 9 | paita
# Processing Record 6 of Set 9 | urzhar
# Processing Record 7 of Set 9 | mwene-ditu
# Processing Record 8 of Set 9 | eyl
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | labasa
# Processing Record 11 of Set 9 | san pedro
# Processing Record 12 of Set 9 | mertoyudan
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | corinto
# Processing Record 15 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 16 of Set 9 | susuman
# Processing Record 17 of Set 9 | san sebastian de la gomera
# Processing Record 18 of Set 9 | boende
# Processing Record 19 of Set 9 | kurmuk
# Processing Record 20 of Set 9 | munnar
# Processing Record 21 of Set 9 | soio
# Processing Record 22 of Set 9 | swift current
# Processing Record 23 of Set 9 | nadym
# Processing Record 24 of Set 9 | luau
# Processing Record 25 of Set 9 | ulsteinvik
# Processing Record 26 of Set 9 | karatau
# Processing Record 27 of Set 9 | san rafael del yuma
# Processing Record 28 of Set 9 | akureyri
# Processing Record 29 of Set 9 | gulf shores
# Processing Record 30 of Set 9 | kibondo
# Processing Record 31 of Set 9 | kimbe
# Processing Record 32 of Set 9 | baykalovo
# Processing Record 33 of Set 9 | plettenberg bay
# Processing Record 34 of Set 9 | kabwe
# Processing Record 35 of Set 9 | uaua
# Processing Record 36 of Set 9 | barah
# Processing Record 37 of Set 9 | adamovka
# Processing Record 38 of Set 9 | kaihua
# Processing Record 39 of Set 9 | onega
# Processing Record 40 of Set 9 | motygino
# Processing Record 41 of Set 9 | kargasok
# Processing Record 42 of Set 9 | alice springs
# Processing Record 43 of Set 9 | eglin village
# Processing Record 44 of Set 9 | lubao
# Processing Record 45 of Set 9 | lhasa
# Processing Record 46 of Set 9 | nogliki
# Processing Record 47 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 9 | chiang klang
# Processing Record 49 of Set 9 | buriti bravo
# Processing Record 0 of Set 10 | shillong
# Processing Record 1 of Set 10 | ghat
# Processing Record 2 of Set 10 | arno
# Processing Record 3 of Set 10 | zeya
# Processing Record 4 of Set 10 | koundara
# Processing Record 5 of Set 10 | kayangel
# Processing Record 6 of Set 10 | inongo
# Processing Record 7 of Set 10 | newport
# Processing Record 8 of Set 10 | hami
# Processing Record 9 of Set 10 | ust-tsilma
# Processing Record 10 of Set 10 | acajutla
# Processing Record 11 of Set 10 | mugia
# Processing Record 12 of Set 10 | cockburn town
# Processing Record 13 of Set 10 | pante makasar
# City not found. Skipping...
# Processing Record 14 of Set 10 | iskateley
# Processing Record 15 of Set 10 | nhamunda
# Processing Record 16 of Set 10 | north bend
# Processing Record 17 of Set 10 | lewiston orchards
# Processing Record 18 of Set 10 | nacala
# Processing Record 19 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 20 of Set 10 | muravlenko
# Processing Record 21 of Set 10 | mogadishu
# Processing Record 22 of Set 10 | altay
# Processing Record 23 of Set 10 | amga
# Processing Record 24 of Set 10 | taro
# Processing Record 25 of Set 10 | karasburg
# Processing Record 26 of Set 10 | as sulayyil
# Processing Record 27 of Set 10 | howard springs
# Processing Record 28 of Set 10 | chokwe
# Processing Record 29 of Set 10 | touros
# Processing Record 30 of Set 10 | dourbali
# Processing Record 31 of Set 10 | pedernales
# Processing Record 32 of Set 10 | mafinga
# Processing Record 33 of Set 10 | hiratacho
# Processing Record 34 of Set 10 | zaozersk
# Processing Record 35 of Set 10 | dunedin
# Processing Record 36 of Set 10 | the pas
# Processing Record 37 of Set 10 | tralee
# Processing Record 38 of Set 10 | letlhakeng
# Processing Record 39 of Set 10 | verkhnevilyuysk
# Processing Record 40 of Set 10 | erdenet
# Processing Record 41 of Set 10 | kant
# Processing Record 42 of Set 10 | laojunmiao
# Processing Record 43 of Set 10 | nova vicosa
# Processing Record 44 of Set 10 | ebon
# Processing Record 45 of Set 10 | orkney
# Processing Record 46 of Set 10 | barra de santo antonio
# Processing Record 47 of Set 10 | ugoofaaru
# Processing Record 48 of Set 10 | el granada
# Processing Record 49 of Set 10 | princeville
# Processing Record 0 of Set 11 | sao lourenco do sul
# Processing Record 1 of Set 11 | nola
# Processing Record 2 of Set 11 | lander
# Processing Record 3 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 11 | santiago del estero
# Processing Record 5 of Set 11 | kayes
# Processing Record 6 of Set 11 | coyhaique
# Processing Record 7 of Set 11 | merritt
# Processing Record 8 of Set 11 | viana do castelo
# Processing Record 9 of Set 11 | la mira
# Processing Record 10 of Set 11 | ciudad bolivar
# Processing Record 11 of Set 11 | papao
# Processing Record 12 of Set 11 | kolonia
# Processing Record 13 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 14 of Set 11 | fedorovskiy
# Processing Record 15 of Set 11 | xining
# Processing Record 16 of Set 11 | takum
# Processing Record 17 of Set 11 | tandil
# Processing Record 18 of Set 11 | adra
# Processing Record 19 of Set 11 | tarawa
# Processing Record 20 of Set 11 | okha
# Processing Record 21 of Set 11 | chayan
# Processing Record 22 of Set 11 | bodaybo
# Processing Record 23 of Set 11 | spring creek
# Processing Record 24 of Set 11 | kavaratti
# Processing Record 25 of Set 11 | nizhneudinsk
# Processing Record 26 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 11 | brandfort
# Processing Record 28 of Set 11 | statesboro
# Processing Record 29 of Set 11 | puerto cabezas
# Processing Record 30 of Set 11 | envira
# Processing Record 31 of Set 11 | mount isa
# Processing Record 32 of Set 11 | juegang
# Processing Record 33 of Set 11 | beinamar
# Processing Record 34 of Set 11 | korla
# Processing Record 35 of Set 11 | oriximina
# Processing Record 36 of Set 11 | natal
# Processing Record 37 of Set 11 | ola
# Processing Record 38 of Set 11 | zuunmod
# Processing Record 39 of Set 11 | igbeti
# Processing Record 40 of Set 11 | fortuna
# Processing Record 41 of Set 11 | vorkuta
# Processing Record 42 of Set 11 | pilar
# Processing Record 43 of Set 11 | volodarsk
# Processing Record 44 of Set 11 | tanumah
# Processing Record 45 of Set 11 | opuwo
# Processing Record 46 of Set 11 | hengchun
# Processing Record 47 of Set 11 | nouvelle france
# Processing Record 48 of Set 11 | ormara
# Processing Record 49 of Set 11 | chonchi
# Processing Record 0 of Set 12 | paradip garh
# Processing Record 1 of Set 12 | san julian
# Processing Record 2 of Set 12 | dolzhanskaya
# Processing Record 3 of Set 12 | eydhafushi
# Processing Record 4 of Set 12 | muisne
# Processing Record 5 of Set 12 | bangassou
# Processing Record 6 of Set 12 | bengkulu
# Processing Record 7 of Set 12 | hastings
# Processing Record 8 of Set 12 | masina
# Processing Record 9 of Set 12 | ati
# Processing Record 10 of Set 12 | jayapura
# Processing Record 11 of Set 12 | broome
# Processing Record 12 of Set 12 | muzayri'
# City not found. Skipping...
# Processing Record 13 of Set 12 | visakhapatnam
# Processing Record 14 of Set 12 | umm kaddadah
# Processing Record 15 of Set 12 | corner brook
# Processing Record 16 of Set 12 | kavali
# Processing Record 17 of Set 12 | el calafate
# Processing Record 18 of Set 12 | greymouth
# Processing Record 19 of Set 12 | kapit
# Processing Record 20 of Set 12 | ust'-ilimsk
# Processing Record 21 of Set 12 | akhtubinsk
# Processing Record 22 of Set 12 | bocana de paiwas
# Processing Record 23 of Set 12 | chaihe
# Processing Record 24 of Set 12 | forster
# Processing Record 25 of Set 12 | anatuya
# Processing Record 26 of Set 12 | kenai
# Processing Record 27 of Set 12 | rosarito
# Processing Record 28 of Set 12 | bestobe
# Processing Record 29 of Set 12 | igrim
# Processing Record 30 of Set 12 | curillo
# Processing Record 31 of Set 12 | porto novo
# Processing Record 32 of Set 12 | hinton
# Processing Record 33 of Set 12 | newman
# Processing Record 34 of Set 12 | nakamura
# Processing Record 35 of Set 12 | chengde
# Processing Record 36 of Set 12 | zhezqazghan
# Processing Record 37 of Set 12 | panacan
# Processing Record 38 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 39 of Set 12 | happy valley-goose bay
# Processing Record 40 of Set 12 | tumayr
# Processing Record 41 of Set 12 | khandyga
# Processing Record 42 of Set 12 | kwang binh
# Processing Record 43 of Set 12 | zouerate
# Processing Record 44 of Set 12 | gaigeturi
# Processing Record 45 of Set 12 | haapajarvi
# Processing Record 46 of Set 12 | pacific grove
# Processing Record 47 of Set 12 | ressano garcia
# Processing Record 48 of Set 12 | salahonda
# Processing Record 49 of Set 12 | elliot
# Processing Record 0 of Set 13 | selizharovo
# Processing Record 1 of Set 13 | mglin
# Processing Record 2 of Set 13 | gardez
# Processing Record 3 of Set 13 | suai
# City not found. Skipping...
# Processing Record 4 of Set 13 | nantucket
# Processing Record 5 of Set 13 | ebebiyin
# Processing Record 6 of Set 13 | ar raqqah
# Processing Record 7 of Set 13 | indianapolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#print(city_data)
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame (city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                         nadi -17.8000  177.4167     21.00        88
# 1               puerto natales -51.7236  -72.4875     -3.48        93
# 2                    adamstown -25.0660 -130.1015     20.76        68
# 3  edinburgh of the seven seas -37.0676  -12.3116     12.83        75
# 4                   vila velha -20.3297  -40.2925     18.30        89
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        0.00      FJ  22-07-2023
# 1         100        0.81      CL  22-07-2023
# 2         100        9.93      PN  22-07-2023
# 3          91       10.00      SH  22-07-2023
# 4          20        1.79      BR  22-07-2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                               nadi -17.8000  177.4167     21.00        88
# 1                     puerto natales -51.7236  -72.4875     -3.48        93
# 2                          adamstown -25.0660 -130.1015     20.76        68
# 3        edinburgh of the seven seas -37.0676  -12.3116     12.83        75
# 4                         vila velha -20.3297  -40.2925     18.30        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        0.00      FJ  22-07-2023
# 1               100        0.81      CL  22-07-2023
# 2               100        9.93      PN  22-07-2023
# 3                91       10.00      SH  22-07-2023
# 4                20        1.79      BR  22-07-2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Wind Speed m/s')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] > 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 6        santa elena de uairen   4.6167  -61.1333     18.42        91
# 7               ribeira grande  38.5167  -28.7000     21.54        88
# 10                      badger  64.8000 -147.5333     21.95        65
# 11                   zhangatas  43.5667   69.7500     35.91        15
# 15                      saipan  15.1355  145.7010     29.39       100
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 6                14        0.53      VE  22-07-2023
# 7                20        2.68      PT  22-07-2023
# 10                0        2.06      US  22-07-2023
# 11               12        6.27      KZ  22-07-2023
# 15               75        5.14      MP  22-07-2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                               nadi -17.8000  177.4167     21.00        88
# 1                     puerto natales -51.7236  -72.4875     -3.48        93
# 2                          adamstown -25.0660 -130.1015     20.76        68
# 3        edinburgh of the seven seas -37.0676  -12.3116     12.83        75
# 4                         vila velha -20.3297  -40.2925     18.30        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        0.00      FJ  22-07-2023
# 1               100        0.81      CL  22-07-2023
# 2               100        9.93      PN  22-07-2023
# 3                91       10.00      SH  22-07-2023
# 4                20        1.79      BR  22-07-2023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()
print(line_eq)
print(f"The correlation between Max Temp and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.2x + 31.57
# The correlation between Max Temp and Latitude is: 0.29975

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-40,-5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()
print(line_eq)
print(f"The correlation between between Max Temp and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = 0.47x + 28.5
# The correlation between between Max Temp and Latitude is: 0.69902

# %% [markdown]
# **Discussion about the linear relationship:**
#     In General Max Temp decreases as the latitude moves away from the equator
#     The correlation for Max temp vs latitude in the southern hemisphere is stronger than the same for the northern hemisphere
#     by roughly a factor of 2. Both correlation coafficients, however, are not strong to conclude a good relationship.
#     The temp range covered in north (0 to 50) is wider than in the rnage coverd in south (-5 to 35)
#     The scatter around the strightline in both cases is wide. The scatter around the straighline in the north is more than in the south. There other factors, such as elevation above mean sea level, that control Temp.
#     Liner relationship does not reflect the relationship between Max Temp and Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(47,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Humidity and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.12x + 71.59
# The correlation between Humidity and Latitude is: 0.01046

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Humidity and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.29x + 65.49
# The correlation between Humidity and Latitude is: 0.04889

# %% [markdown]
# **Discussion about the linear relationship:
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Humidity and Latitude in both region when using straighlines.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(47,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Cloudiness and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.12x + 63.58
# The correlation between Cloudiness and Latitude is: 0.00382

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-50,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Cloudiness and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.99x + 32.43
# The correlation between Cloudiness and Latitude is: 0.12474

# %% [markdown]
# **Discussion about the linear relationship:**
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Cloudiness and Latitude in both region when using straighlines.
#     Again, other factors should be considerd to determin a relationship between Cloudiness and Latitude.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(50,11),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
print(line_eq)
print(f"The correlation between Wind Speed and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.01x + 3.99
# The correlation between Wind Speed and Latitude is: 0.0061

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-30,13),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
print(line_eq)
print(f"The correlation between Wind Speed and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = 0.0x + 3.78
# The correlation between Wind Speed and Latitude is: 0.0

# %% [markdown]
# **Discussion about the linear relationship:**
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Wind Speed and Latitude in both region when using straighlines.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.
