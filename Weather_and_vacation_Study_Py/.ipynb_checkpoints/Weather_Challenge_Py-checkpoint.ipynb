# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#Running initial example first to find location for each parameter
main_url = "http://api.openweathermap.org/data/2.5/weather?"
url = f"{main_url}appid={weather_api_key}&q="
city = "Melbourne"
response = requests.get(url + city)
responce_json = response.json()
print(json.dumps(responce_json, indent=4, sort_keys=True))

city_lat = responce_json["coord"]["lat"]
print(city_lat)
city_lng = responce_json["coord"]["lon"]
print(city_lng)
city_max_temp = responce_json["main"]["temp_max"]
print(city_max_temp)
city_humidity = responce_json["main"]["humidity"]
print (city_humidity)
city_clouds = responce_json["clouds"]["all"]
print(city_clouds)
city_wind = responce_json["wind"]["speed"]
print(city_wind)
city_country = responce_json["sys"]["country"]
print(city_country)
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.0836,
#         "lon": -80.6081
#     },
#     "dt": 1690007504,
#     "id": 4163971,
#     "main": {
#         "feels_like": 299.47,
#         "humidity": 83,
#         "pressure": 1014,
#         "temp": 299.47,
#         "temp_max": 301.14,
#         "temp_min": 297.6
#     },
#     "name": "Melbourne",
#     "sys": {
#         "country": "US",
#         "id": 2007578,
#         "sunrise": 1690022345,
#         "sunset": 1690071499,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 5.14
#     }
# }
# 28.0836
# -80.6081
# 301.14
# 83
# 0
# 5.14
# US

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
main_url = "http://api.openweathermap.org/data/2.5/weather?"
#declaring units as metrics
units = "metric"
#url
url = f"{main_url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
today = datetime.today().strftime('%d-%m-%Y')

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    response = requests.get(city_url)
    #print(json.dumps(response_json, indent=4, sort_keys=True))
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #print(json.dumps(city_weather, indent=4, sort_keys=True))

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        #print(city_lat)
        city_lng = city_weather["coord"]["lon"]
        #print(city_lng)
        city_max_temp = city_weather["main"]["temp_max"]
        #print(city_max_temp)
        city_humidity = city_weather["main"]["humidity"]
        #print (city_humidity)
        city_clouds = city_weather["clouds"]["all"]
        #print(city_clouds)
        city_wind = city_weather["wind"]["speed"]
        #print(city_wind)
        city_country = city_weather["sys"]["country"]
        #print(city_country)
        city_date = today

        #Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | san antonio de pale
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | stillwater
# Processing Record 10 of Set 1 | shanhecun
# Processing Record 11 of Set 1 | anna regina
# Processing Record 12 of Set 1 | baishan
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | isafjordur
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 1 | boyolangu
# Processing Record 19 of Set 1 | olonkinbyen
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | puerto natales
# Processing Record 24 of Set 1 | adamstown
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | popondetta
# Processing Record 28 of Set 1 | chernomorskoye
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | amga
# Processing Record 32 of Set 1 | tromso
# Processing Record 33 of Set 1 | lihue
# Processing Record 34 of Set 1 | port macquarie
# Processing Record 35 of Set 1 | stephenville
# Processing Record 36 of Set 1 | waitangi
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | anadyr
# Processing Record 39 of Set 1 | la romana
# Processing Record 40 of Set 1 | dunedin
# Processing Record 41 of Set 1 | codrington
# Processing Record 42 of Set 1 | tual
# Processing Record 43 of Set 1 | seven pagodas
# Processing Record 44 of Set 1 | zelenogorsk
# Processing Record 45 of Set 1 | mamadysh
# Processing Record 46 of Set 1 | bonthe
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | mata-utu
# Processing Record 49 of Set 1 | ust'-kut
# Processing Record 50 of Set 1 | invercargill
# Processing Record 0 of Set 2 | larkird
# Processing Record 1 of Set 2 | kitimat
# Processing Record 2 of Set 2 | nova vicosa
# Processing Record 3 of Set 2 | coyhaique
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | jinchang
# Processing Record 6 of Set 2 | taber
# Processing Record 7 of Set 2 | kone
# Processing Record 8 of Set 2 | general acha
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | lyubim
# Processing Record 11 of Set 2 | wailua homesteads
# Processing Record 12 of Set 2 | nadi
# Processing Record 13 of Set 2 | tura
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | guane
# Processing Record 16 of Set 2 | tukrah
# Processing Record 17 of Set 2 | bilibino
# Processing Record 18 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | pyapon
# Processing Record 21 of Set 2 | lodwar
# Processing Record 22 of Set 2 | arauquita
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | dawei
# Processing Record 25 of Set 2 | miandrivazo
# Processing Record 26 of Set 2 | sultanah
# Processing Record 27 of Set 2 | crane
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | bei'an
# Processing Record 30 of Set 2 | la ronge
# Processing Record 31 of Set 2 | papatowai
# Processing Record 32 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 2 | cockburn town
# Processing Record 34 of Set 2 | kiama
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | alice springs
# Processing Record 38 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 39 of Set 2 | vanimo
# Processing Record 40 of Set 2 | margaret river
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | wenchang
# Processing Record 43 of Set 2 | kenai
# Processing Record 44 of Set 2 | rehoboth
# Processing Record 45 of Set 2 | floro
# Processing Record 46 of Set 2 | nyurba
# Processing Record 47 of Set 2 | nadym
# Processing Record 48 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 49 of Set 2 | port saint john's
# Processing Record 0 of Set 3 | las tablas
# Processing Record 1 of Set 3 | hawaiian paradise park
# Processing Record 2 of Set 3 | choma
# Processing Record 3 of Set 3 | talakan
# Processing Record 4 of Set 3 | baardheere
# Processing Record 5 of Set 3 | queenstown
# Processing Record 6 of Set 3 | portland
# Processing Record 7 of Set 3 | eyl
# Processing Record 8 of Set 3 | lepsy
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | selty
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | antsiranana
# Processing Record 13 of Set 3 | nouadhibou
# Processing Record 14 of Set 3 | west island
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | choyr
# Processing Record 17 of Set 3 | ust'-kulom
# Processing Record 18 of Set 3 | kailua-kona
# Processing Record 19 of Set 3 | winnemucca
# Processing Record 20 of Set 3 | batu pahat
# Processing Record 21 of Set 3 | peace river
# Processing Record 22 of Set 3 | tolanaro
# Processing Record 23 of Set 3 | santa ana
# Processing Record 24 of Set 3 | nagqu
# Processing Record 25 of Set 3 | seogwipo
# City not found. Skipping...
# Processing Record 26 of Set 3 | carutapera
# Processing Record 27 of Set 3 | al ghayzah
# Processing Record 28 of Set 3 | hurghada
# Processing Record 29 of Set 3 | kerikeri
# Processing Record 30 of Set 3 | galesong
# Processing Record 31 of Set 3 | sanluri
# Processing Record 32 of Set 3 | baker city
# Processing Record 33 of Set 3 | stanley
# Processing Record 34 of Set 3 | kidal
# Processing Record 35 of Set 3 | fort st. john
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | muynoq
# Processing Record 38 of Set 3 | lander
# Processing Record 39 of Set 3 | shingu
# Processing Record 40 of Set 3 | lake alfred
# Processing Record 41 of Set 3 | nguigmi
# Processing Record 42 of Set 3 | belmonte
# Processing Record 43 of Set 3 | port mathurin
# Processing Record 44 of Set 3 | igarka
# Processing Record 45 of Set 3 | muroto-misakicho
# Processing Record 46 of Set 3 | khandyga
# Processing Record 47 of Set 3 | nova sintra
# Processing Record 48 of Set 3 | masterton
# Processing Record 49 of Set 3 | uturoa
# Processing Record 0 of Set 4 | narasannapeta
# Processing Record 1 of Set 4 | flin flon
# Processing Record 2 of Set 4 | kolonia
# Processing Record 3 of Set 4 | tutoia
# Processing Record 4 of Set 4 | north bay
# Processing Record 5 of Set 4 | marquette
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | wotho
# Processing Record 8 of Set 4 | magdagachi
# Processing Record 9 of Set 4 | benguela
# Processing Record 10 of Set 4 | tieli
# Processing Record 11 of Set 4 | constantia
# Processing Record 12 of Set 4 | mount pearl
# Processing Record 13 of Set 4 | sisimiut
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | bhamo
# Processing Record 16 of Set 4 | badger
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | pimenta bueno
# Processing Record 19 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 4 | jamestown
# Processing Record 21 of Set 4 | la'ie
# Processing Record 22 of Set 4 | gilgit
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | manismata
# Processing Record 25 of Set 4 | kayes
# Processing Record 26 of Set 4 | kharp
# Processing Record 27 of Set 4 | mrakovo
# Processing Record 28 of Set 4 | fale old settlement
# Processing Record 29 of Set 4 | minas de marcona
# Processing Record 30 of Set 4 | havre
# Processing Record 31 of Set 4 | ginir
# Processing Record 32 of Set 4 | taounate
# Processing Record 33 of Set 4 | middelburg
# Processing Record 34 of Set 4 | novodvinsk
# Processing Record 35 of Set 4 | anta
# Processing Record 36 of Set 4 | korla
# Processing Record 37 of Set 4 | raduzhny
# Processing Record 38 of Set 4 | palu
# Processing Record 39 of Set 4 | kill devil hills
# Processing Record 40 of Set 4 | bapatla
# Processing Record 41 of Set 4 | ritchie
# Processing Record 42 of Set 4 | severo-yeniseyskiy
# Processing Record 43 of Set 4 | vilyuchinsk
# Processing Record 44 of Set 4 | puerto baquerizo moreno
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | praia da vitoria
# Processing Record 47 of Set 4 | varde
# Processing Record 48 of Set 4 | bubaque
# Processing Record 49 of Set 4 | nantucket
# Processing Record 0 of Set 5 | ingeniero guillermo n. juarez
# Processing Record 1 of Set 5 | staryy dobrotvir
# Processing Record 2 of Set 5 | kiffa
# Processing Record 3 of Set 5 | kingston
# Processing Record 4 of Set 5 | springbok
# Processing Record 5 of Set 5 | santiago papasquiaro
# City not found. Skipping...
# Processing Record 6 of Set 5 | rongelap
# Processing Record 7 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 8 of Set 5 | punta cardon
# Processing Record 9 of Set 5 | mutoko
# Processing Record 10 of Set 5 | fetsund
# Processing Record 11 of Set 5 | camana
# Processing Record 12 of Set 5 | maffra
# Processing Record 13 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 5 | iquitos
# Processing Record 15 of Set 5 | casteljaloux
# Processing Record 16 of Set 5 | razole
# Processing Record 17 of Set 5 | pokhara
# Processing Record 18 of Set 5 | vila franca do campo
# Processing Record 19 of Set 5 | suntar
# Processing Record 20 of Set 5 | dudinka
# Processing Record 21 of Set 5 | bissau
# Processing Record 22 of Set 5 | qaqortoq
# Processing Record 23 of Set 5 | haiku-pauwela
# Processing Record 24 of Set 5 | yamada
# Processing Record 25 of Set 5 | udachny
# Processing Record 26 of Set 5 | ghadamis
# Processing Record 27 of Set 5 | yuzhno-kurilsk
# Processing Record 28 of Set 5 | gizo
# Processing Record 29 of Set 5 | sao paulo de olivenca
# Processing Record 30 of Set 5 | st. john's
# Processing Record 31 of Set 5 | aasiaat
# Processing Record 32 of Set 5 | palikir - national government center
# Processing Record 33 of Set 5 | el granada
# Processing Record 34 of Set 5 | remire-montjoly
# Processing Record 35 of Set 5 | adra
# Processing Record 36 of Set 5 | camara de lobos
# Processing Record 37 of Set 5 | bikapur
# Processing Record 38 of Set 5 | arteche
# Processing Record 39 of Set 5 | mandalgovi
# Processing Record 40 of Set 5 | la passe
# Processing Record 41 of Set 5 | sibolga
# Processing Record 42 of Set 5 | saguenay
# Processing Record 43 of Set 5 | blackfoot
# Processing Record 44 of Set 5 | vera
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | tsiombe
# Processing Record 47 of Set 5 | sarigerme
# Processing Record 48 of Set 5 | gofitskoye
# Processing Record 49 of Set 5 | deqen
# Processing Record 0 of Set 6 | weno
# Processing Record 1 of Set 6 | puerto penasco
# Processing Record 2 of Set 6 | talnakh
# Processing Record 3 of Set 6 | dwarka
# Processing Record 4 of Set 6 | hammerfest
# Processing Record 5 of Set 6 | bayanhongor
# Processing Record 6 of Set 6 | novovarshavka
# Processing Record 7 of Set 6 | buckeye
# Processing Record 8 of Set 6 | al 'amarah
# Processing Record 9 of Set 6 | al jubayl
# Processing Record 10 of Set 6 | evinayong
# Processing Record 11 of Set 6 | ambon
# Processing Record 12 of Set 6 | enewetak
# Processing Record 13 of Set 6 | bohuslav
# Processing Record 14 of Set 6 | farafangana
# Processing Record 15 of Set 6 | ekenas
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | pundong
# Processing Record 18 of Set 6 | hailey
# Processing Record 19 of Set 6 | atafu village
# Processing Record 20 of Set 6 | broken hill
# Processing Record 21 of Set 6 | el calafate
# Processing Record 22 of Set 6 | itoman
# Processing Record 23 of Set 6 | shashemene
# Processing Record 24 of Set 6 | ust-nera
# Processing Record 25 of Set 6 | afaahiti
# Processing Record 26 of Set 6 | san patricio
# Processing Record 27 of Set 6 | port lincoln
# Processing Record 28 of Set 6 | prince rupert
# Processing Record 29 of Set 6 | yigo village
# Processing Record 30 of Set 6 | thunder bay
# Processing Record 31 of Set 6 | whitehorse
# Processing Record 32 of Set 6 | bushehr
# Processing Record 33 of Set 6 | acajutla
# Processing Record 34 of Set 6 | tazovsky
# Processing Record 35 of Set 6 | okondja
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | le port
# Processing Record 38 of Set 6 | fortuna
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | tarko-sale
# Processing Record 41 of Set 6 | sao joao da barra
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | fort stockton
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | vilyuysk
# Processing Record 46 of Set 6 | riberalta
# Processing Record 47 of Set 6 | riachao
# Processing Record 48 of Set 6 | turuntayevo
# Processing Record 49 of Set 6 | hendrina
# Processing Record 0 of Set 7 | awash
# Processing Record 1 of Set 7 | new norfolk
# Processing Record 2 of Set 7 | alagoa grande
# Processing Record 3 of Set 7 | taunggyi
# Processing Record 4 of Set 7 | champerico
# Processing Record 5 of Set 7 | dolores
# Processing Record 6 of Set 7 | selebi-phikwe
# Processing Record 7 of Set 7 | corral de bustos
# Processing Record 8 of Set 7 | beyneu
# Processing Record 9 of Set 7 | tank
# Processing Record 10 of Set 7 | manokwari
# Processing Record 11 of Set 7 | anloga
# Processing Record 12 of Set 7 | tobelo
# Processing Record 13 of Set 7 | porto belo
# Processing Record 14 of Set 7 | kayangel
# Processing Record 15 of Set 7 | pran buri
# Processing Record 16 of Set 7 | murray
# Processing Record 17 of Set 7 | saudarkrokur
# Processing Record 18 of Set 7 | pigeon forge
# Processing Record 19 of Set 7 | yambio
# Processing Record 20 of Set 7 | bikenibeu village
# Processing Record 21 of Set 7 | vado ligure
# Processing Record 22 of Set 7 | carloforte
# Processing Record 23 of Set 7 | puerto rico
# Processing Record 24 of Set 7 | mwinilunga
# Processing Record 25 of Set 7 | mhangura
# Processing Record 26 of Set 7 | okakarara
# Processing Record 27 of Set 7 | vadso
# Processing Record 28 of Set 7 | loch garman
# Processing Record 29 of Set 7 | kirakira
# Processing Record 30 of Set 7 | minas
# Processing Record 31 of Set 7 | keetmanshoop
# Processing Record 32 of Set 7 | polyarnyy
# Processing Record 33 of Set 7 | keflavik
# Processing Record 34 of Set 7 | iskateley
# Processing Record 35 of Set 7 | kapsan-up
# Processing Record 36 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 37 of Set 7 | howard springs
# Processing Record 38 of Set 7 | sheridan
# Processing Record 39 of Set 7 | saynshand
# Processing Record 40 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 7 | xihe
# Processing Record 42 of Set 7 | alaghsas
# Processing Record 43 of Set 7 | aginskoye
# Processing Record 44 of Set 7 | gaalkacyo
# Processing Record 45 of Set 7 | logan
# Processing Record 46 of Set 7 | jayapura
# Processing Record 47 of Set 7 | gebeit
# Processing Record 48 of Set 7 | al abyar
# Processing Record 49 of Set 7 | birjand
# Processing Record 0 of Set 8 | ripanj
# Processing Record 1 of Set 8 | oriximina
# Processing Record 2 of Set 8 | vorgashor
# Processing Record 3 of Set 8 | ugoofaaru
# Processing Record 4 of Set 8 | inhambane
# Processing Record 5 of Set 8 | okhotsk
# Processing Record 6 of Set 8 | villa gesell
# Processing Record 7 of Set 8 | cidreira
# Processing Record 8 of Set 8 | sinabang
# Processing Record 9 of Set 8 | puerto asis
# Processing Record 10 of Set 8 | wewak
# Processing Record 11 of Set 8 | sitka
# Processing Record 12 of Set 8 | mount gambier
# Processing Record 13 of Set 8 | timimoun
# Processing Record 14 of Set 8 | sechura
# Processing Record 15 of Set 8 | mstsislaw
# Processing Record 16 of Set 8 | brisas de zicatela
# Processing Record 17 of Set 8 | le marin
# Processing Record 18 of Set 8 | mugia
# Processing Record 19 of Set 8 | banjarmasin
# Processing Record 20 of Set 8 | ocara
# Processing Record 21 of Set 8 | betio village
# Processing Record 22 of Set 8 | nuuk
# Processing Record 23 of Set 8 | shiraz
# Processing Record 24 of Set 8 | boise
# Processing Record 25 of Set 8 | ukrainka
# Processing Record 26 of Set 8 | jalalpur jattan
# Processing Record 27 of Set 8 | prince george
# Processing Record 28 of Set 8 | klaksvik
# Processing Record 29 of Set 8 | marat
# Processing Record 30 of Set 8 | utrik
# Processing Record 31 of Set 8 | forest lake
# Processing Record 32 of Set 8 | tadine
# Processing Record 33 of Set 8 | metkovic
# Processing Record 34 of Set 8 | lusambo
# Processing Record 35 of Set 8 | gadzhiyevo
# Processing Record 36 of Set 8 | shahr-e babak
# Processing Record 37 of Set 8 | butte
# Processing Record 38 of Set 8 | zeya
# Processing Record 39 of Set 8 | nelson bay
# Processing Record 40 of Set 8 | heathmont
# Processing Record 41 of Set 8 | kununurra
# Processing Record 42 of Set 8 | isoka
# Processing Record 43 of Set 8 | coquimbo
# Processing Record 44 of Set 8 | kapuskasing
# Processing Record 45 of Set 8 | ljusdal
# Processing Record 46 of Set 8 | launceston
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | katsuura
# Processing Record 49 of Set 8 | hadibu
# Processing Record 0 of Set 9 | zhelezinka
# Processing Record 1 of Set 9 | horta
# Processing Record 2 of Set 9 | lata
# Processing Record 3 of Set 9 | keminmaa
# Processing Record 4 of Set 9 | bamboo flat
# Processing Record 5 of Set 9 | lulea
# Processing Record 6 of Set 9 | dickinson
# Processing Record 7 of Set 9 | hovd
# Processing Record 8 of Set 9 | beau vallon
# Processing Record 9 of Set 9 | isle of lewis
# City not found. Skipping...
# Processing Record 10 of Set 9 | north battleford
# Processing Record 11 of Set 9 | taos
# Processing Record 12 of Set 9 | peruibe
# Processing Record 13 of Set 9 | shahrud
# Processing Record 14 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 15 of Set 9 | antalaha
# Processing Record 16 of Set 9 | newnham
# Processing Record 17 of Set 9 | campechuela
# Processing Record 18 of Set 9 | nemuro
# Processing Record 19 of Set 9 | i-n-salah
# Processing Record 20 of Set 9 | mitsamiouli
# Processing Record 21 of Set 9 | bayston hill
# Processing Record 22 of Set 9 | lerwick
# Processing Record 23 of Set 9 | carnarvon
# Processing Record 24 of Set 9 | port hedland
# Processing Record 25 of Set 9 | mundra
# Processing Record 26 of Set 9 | opuwo
# Processing Record 27 of Set 9 | bouna
# Processing Record 28 of Set 9 | papao
# Processing Record 29 of Set 9 | cheremushki
# Processing Record 30 of Set 9 | camayenne
# Processing Record 31 of Set 9 | qamdo
# Processing Record 32 of Set 9 | mana
# Processing Record 33 of Set 9 | ketchikan
# Processing Record 34 of Set 9 | ghat
# Processing Record 35 of Set 9 | kargil
# Processing Record 36 of Set 9 | la sarre
# Processing Record 37 of Set 9 | gubkinskiy
# Processing Record 38 of Set 9 | boca do acre
# Processing Record 39 of Set 9 | malabar
# Processing Record 40 of Set 9 | yuci
# Processing Record 41 of Set 9 | el porvenir
# Processing Record 42 of Set 9 | nikolayevsk-on-amure
# Processing Record 43 of Set 9 | coracora
# Processing Record 44 of Set 9 | mao
# Processing Record 45 of Set 9 | natal
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | santa teresa
# Processing Record 48 of Set 9 | manta
# Processing Record 49 of Set 9 | egilsstadir
# Processing Record 0 of Set 10 | al-`ula
# City not found. Skipping...
# Processing Record 1 of Set 10 | asau village
# City not found. Skipping...
# Processing Record 2 of Set 10 | alzamay
# Processing Record 3 of Set 10 | cameron park
# Processing Record 4 of Set 10 | buka
# Processing Record 5 of Set 10 | shiyan
# Processing Record 6 of Set 10 | kolokani
# Processing Record 7 of Set 10 | holalkere
# Processing Record 8 of Set 10 | aykhal
# Processing Record 9 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 10 | slutsk
# Processing Record 11 of Set 10 | mariental
# Processing Record 12 of Set 10 | armacao de buzios
# Processing Record 13 of Set 10 | sittwe
# Processing Record 14 of Set 10 | isangel
# Processing Record 15 of Set 10 | pibor
# City not found. Skipping...
# Processing Record 16 of Set 10 | slave lake
# Processing Record 17 of Set 10 | horishni plavni
# Processing Record 18 of Set 10 | sao vicente
# Processing Record 19 of Set 10 | kismayo
# Processing Record 20 of Set 10 | hassi messaoud
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | boende
# Processing Record 23 of Set 10 | torit
# Processing Record 24 of Set 10 | pisco
# Processing Record 25 of Set 10 | raton
# Processing Record 26 of Set 10 | kakching
# Processing Record 27 of Set 10 | aldama
# Processing Record 28 of Set 10 | nuku'alofa
# Processing Record 29 of Set 10 | tomohon
# Processing Record 30 of Set 10 | griffith
# Processing Record 31 of Set 10 | kamiiso
# Processing Record 32 of Set 10 | santa rita
# Processing Record 33 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 34 of Set 10 | colonia
# Processing Record 35 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 10 | leava
# Processing Record 37 of Set 10 | aberdeen
# Processing Record 38 of Set 10 | flying fish cove
# Processing Record 39 of Set 10 | naze
# Processing Record 40 of Set 10 | saipan
# Processing Record 41 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 42 of Set 10 | hrodna
# Processing Record 43 of Set 10 | micco
# Processing Record 44 of Set 10 | edd
# Processing Record 45 of Set 10 | saint-joseph
# Processing Record 46 of Set 10 | saldanha
# Processing Record 47 of Set 10 | tsiroanomandidy
# Processing Record 48 of Set 10 | sona
# Processing Record 49 of Set 10 | cestos city
# Processing Record 0 of Set 11 | ceerigaabo
# Processing Record 1 of Set 11 | pontian kechil
# Processing Record 2 of Set 11 | talara
# Processing Record 3 of Set 11 | svay rieng
# Processing Record 4 of Set 11 | kyren
# Processing Record 5 of Set 11 | selfoss
# Processing Record 6 of Set 11 | mauganj
# Processing Record 7 of Set 11 | ujae
# Processing Record 8 of Set 11 | guerrero negro
# Processing Record 9 of Set 11 | cambria
# Processing Record 10 of Set 11 | artova
# Processing Record 11 of Set 11 | yantzaza
# Processing Record 12 of Set 11 | karratha
# Processing Record 13 of Set 11 | illizi
# Processing Record 14 of Set 11 | tejen
# Processing Record 15 of Set 11 | metlili chaamba
# Processing Record 16 of Set 11 | charters towers
# Processing Record 17 of Set 11 | frontera
# Processing Record 18 of Set 11 | melekeok village
# Processing Record 19 of Set 11 | kuqa
# Processing Record 20 of Set 11 | chonchi
# Processing Record 21 of Set 11 | tafuna
# Processing Record 22 of Set 11 | hafar al-batin
# Processing Record 23 of Set 11 | maxixe
# Processing Record 24 of Set 11 | conduaga
# Processing Record 25 of Set 11 | reedsburg
# Processing Record 26 of Set 11 | axim
# Processing Record 27 of Set 11 | belyayevka
# Processing Record 28 of Set 11 | mejit
# Processing Record 29 of Set 11 | pandan
# Processing Record 30 of Set 11 | zanjan
# Processing Record 31 of Set 11 | klyuchi
# Processing Record 32 of Set 11 | quiberon
# Processing Record 33 of Set 11 | bardaskan
# City not found. Skipping...
# Processing Record 34 of Set 11 | genhe
# Processing Record 35 of Set 11 | cooper's town
# Processing Record 36 of Set 11 | happy valley-goose bay
# Processing Record 37 of Set 11 | toliara
# Processing Record 38 of Set 11 | diosig
# Processing Record 39 of Set 11 | santa rosa del sara
# City not found. Skipping...
# Processing Record 40 of Set 11 | howrah
# Processing Record 41 of Set 11 | kapa'a
# Processing Record 42 of Set 11 | alsunga
# Processing Record 43 of Set 11 | bengkulu
# Processing Record 44 of Set 11 | general roca
# Processing Record 45 of Set 11 | gongzhuling
# Processing Record 46 of Set 11 | fort bragg
# Processing Record 47 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 48 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 49 of Set 11 | kanel
# Processing Record 0 of Set 12 | callao
# Processing Record 1 of Set 12 | wanning
# Processing Record 2 of Set 12 | pangkalan brandan
# Processing Record 3 of Set 12 | sitia
# Processing Record 4 of Set 12 | castillos
# Processing Record 5 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 6 of Set 12 | neryungri
# Processing Record 7 of Set 12 | vilhena
# Processing Record 8 of Set 12 | novosergiyevka
# Processing Record 9 of Set 12 | tofol
# Processing Record 10 of Set 12 | morehead city
# Processing Record 11 of Set 12 | palmer
# Processing Record 12 of Set 12 | muslyumovo
# Processing Record 13 of Set 12 | kaitong
# Processing Record 14 of Set 12 | micheweni
# Processing Record 15 of Set 12 | williams lake
# Processing Record 16 of Set 12 | tondano
# Processing Record 17 of Set 12 | sao felix do xingu
# Processing Record 18 of Set 12 | ulan bator
# Processing Record 19 of Set 12 | pyhajarvi
# Processing Record 20 of Set 12 | westport
# Processing Record 21 of Set 12 | grand-fort-philippe
# Processing Record 22 of Set 12 | palmares do sul
# Processing Record 23 of Set 12 | nizhniy odes
# Processing Record 24 of Set 12 | devonport
# Processing Record 25 of Set 12 | namsos
# Processing Record 26 of Set 12 | lazaro cardenas
# Processing Record 27 of Set 12 | wau
# Processing Record 28 of Set 12 | cabinda
# Processing Record 29 of Set 12 | ba
# City not found. Skipping...
# Processing Record 30 of Set 12 | betafo
# Processing Record 31 of Set 12 | mzimba
# Processing Record 32 of Set 12 | sao joao do piaui
# Processing Record 33 of Set 12 | pangai
# Processing Record 34 of Set 12 | oyama
# Processing Record 35 of Set 12 | grafton
# Processing Record 36 of Set 12 | san sebastian de la gomera
# Processing Record 37 of Set 12 | ma'rib
# Processing Record 38 of Set 12 | chetwayi
# Processing Record 39 of Set 12 | agat village
# Processing Record 40 of Set 12 | ta`u
# Processing Record 41 of Set 12 | mermoz boabab
# Processing Record 42 of Set 12 | altamira
# Processing Record 43 of Set 12 | lushun
# Processing Record 44 of Set 12 | zhezqazghan
# Processing Record 45 of Set 12 | sokcho
# Processing Record 46 of Set 12 | san juan
# Processing Record 47 of Set 12 | la paz
# Processing Record 48 of Set 12 | mitu
# Processing Record 49 of Set 12 | ar ruways
# Processing Record 0 of Set 13 | bairnsdale
# Processing Record 1 of Set 13 | khanty-mansiysk
# Processing Record 2 of Set 13 | olinda
# Processing Record 3 of Set 13 | ambazac
# Processing Record 4 of Set 13 | honefoss
# Processing Record 5 of Set 13 | barra de santo antonio
# Processing Record 6 of Set 13 | koungou
# Processing Record 7 of Set 13 | cargados carajos
# City not found. Skipping...
# Processing Record 8 of Set 13 | bodaybo
# Processing Record 9 of Set 13 | bayji
# Processing Record 10 of Set 13 | subaykhan
# Processing Record 11 of Set 13 | cassia
# Processing Record 12 of Set 13 | porto torres
# Processing Record 13 of Set 13 | novyy urgal
# Processing Record 14 of Set 13 | ploneour-lanvern
# Processing Record 15 of Set 13 | qujing
# Processing Record 16 of Set 13 | sturgis
# Processing Record 17 of Set 13 | malanje
# Processing Record 18 of Set 13 | tvoroyri
# Processing Record 19 of Set 13 | umluj
# Processing Record 20 of Set 13 | akjoujt
# Processing Record 21 of Set 13 | yuzhno-sakhalinsk
# Processing Record 22 of Set 13 | ulladulla
# Processing Record 23 of Set 13 | ntungamo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#print(city_data)
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame (city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          597
# Lat           597
# Lng           597
# Max Temp      597
# Humidity      597
# Cloudiness    597
# Wind Speed    597
# Country       597
# Date          597
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0              iqaluit  63.7506 -68.5145      4.85       100          75
# 1           bredasdorp -34.5322  20.0403      8.82        66         100
# 2  san antonio de pale  -1.4014   5.6325     23.04        76         100
# 3            grytviken -54.2811 -36.5092     -2.54        82         100
# 4         longyearbyen  78.2186  15.6401      7.91        66          75
#
#    Wind Speed Country        Date
# 0        0.00      CA  22-07-2023
# 1        1.86      ZA  22-07-2023
# 2        5.75      GQ  22-07-2023
# 3        5.60      GS  22-07-2023
# 4        3.09      SJ  22-07-2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                    iqaluit  63.7506 -68.5145      4.85       100
# 1                 bredasdorp -34.5322  20.0403      8.82        66
# 2        san antonio de pale  -1.4014   5.6325     23.04        76
# 3                  grytviken -54.2811 -36.5092     -2.54        82
# 4               longyearbyen  78.2186  15.6401      7.91        66
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        0.00      CA  22-07-2023
# 1               100        1.86      ZA  22-07-2023
# 2               100        5.75      GQ  22-07-2023
# 3               100        5.60      GS  22-07-2023
# 4                75        3.09      SJ  22-07-2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()


# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Wind Speed m/s')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] > 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iqaluit  63.7506  -68.5145      4.85       100          75
# 4        longyearbyen  78.2186   15.6401      7.91        66          75
# 7              bethel  41.3712  -73.4140     20.93        86           0
# 8          stillwater  36.1156  -97.0584     22.15        91           0
# 9           shanhecun  44.7000  127.2000     29.17        69         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      CA  22-07-2023
# 4              3.09      SJ  22-07-2023
# 7              0.00      US  22-07-2023
# 8              2.06      US  22-07-2023
# 9              0.74      CN  22-07-2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                 bredasdorp -34.5322   20.0403      8.82        66
# 2        san antonio de pale  -1.4014    5.6325     23.04        76
# 3                  grytviken -54.2811  -36.5092     -2.54        82
# 5               puerto ayora  -0.7393  -90.3518     24.57        81
# 6              blackmans bay -43.0167  147.3167     13.07        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1               100        1.86      ZA  22-07-2023
# 2               100        5.75      GQ  22-07-2023
# 3               100        5.60      GS  22-07-2023
# 5                94        4.43      EC  22-07-2023
# 6               100        2.78      AU  22-07-2023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()
print(line_eq)
print(f"The correlation between Max Temp and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.21x + 32.03
# The correlation between Max Temp and Latitude is: 0.30265

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-40,-5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()
print(line_eq)
print(f"The correlation between between Max Temp and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = 0.45x + 28.26
# The correlation between between Max Temp and Latitude is: 0.644

# %% [markdown]
# **Discussion about the linear relationship:**
#     In General Max Temp decreases as the latitude moves away from the equator
#     The correlation for Max temp vs latitude in the southern hemisphere is stronger than the same for the northern hemisphere
#     by roughly a factor of 2. Both correlation coafficients, however, are not strong to conclude a good relationship.
#     The temp range covered in north (0 to 50) is wider than in the rnage coverd in south (-5 to 35)
#     The scatter around the strightline in both cases is wide. The scatter around the straighline in the north is more than in the south. There other factors, such as elevation above mean sea level, that control Temp.
#     Liner relationship does not reflect the relationship between Max Temp and Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(47,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Humidity and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.06x + 68.45
# The correlation between Humidity and Latitude is: 0.00239

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Humidity and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.14x + 66.74
# The correlation between Humidity and Latitude is: 0.00826

# %% [markdown]
# **Discussion about the linear relationship:
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Humidity and Latitude in both region when using straighlines.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(47,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Cloudiness and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.11x + 63.9
# The correlation between Cloudiness and Latitude is: 0.00265

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-50,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Cloudiness and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -1.02x + 24.95
# The correlation between Cloudiness and Latitude is: 0.11711

# %% [markdown]
# **Discussion about the linear relationship:**
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Cloudiness and Latitude in both region when using straighlines.
#     Again, other factors should be considerd to determin a relationship between Cloudiness and Latitude.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(50,11),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
print(line_eq)
print(f"The correlation between Wind Speed and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.02x + 4.27
# The correlation between Wind Speed and Latitude is: 0.01938

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-30,13),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
print(line_eq)
print(f"The correlation between Wind Speed and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.01x + 3.55
# The correlation between Wind Speed and Latitude is: 0.00188

# %% [markdown]
# **Discussion about the linear relationship:**
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Wind Speed and Latitude in both region when using straighlines.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.
