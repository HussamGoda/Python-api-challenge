# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#Running initial example first to find location for each parameter
main_url = "http://api.openweathermap.org/data/2.5/weather?"
url = f"{main_url}appid={weather_api_key}&q="
city = "Melbourne"
url_1 = url + city
print(url_1)
#print("http://api.openweathermap.org/data/2.5/weather?q=melbourne&appid=fe048bd477e5afd93e60a0f6a4bc77d8")
response = requests.get(url + city)
responce_json = response.json()
print(json.dumps(responce_json, indent=4, sort_keys=True))

city_lat = responce_json["coord"]["lat"]
print(city_lat)
city_lng = responce_json["coord"]["lon"]
print(city_lng)
city_max_temp = responce_json["main"]["temp_max"]
print(city_max_temp)
city_humidity = responce_json["main"]["humidity"]
print (city_humidity)
city_clouds = responce_json["clouds"]["all"]
print(city_clouds)
city_wind = responce_json["wind"]["speed"]
print(city_wind)
city_country = responce_json["sys"]["country"]
print(city_country)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=fe048bd477e5afd93e60a0f6a4bc77d8&q=Melbourne
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.0836,
#         "lon": -80.6081
#     },
#     "dt": 1689997568,
#     "id": 4163971,
#     "main": {
#         "feels_like": 303.59,
#         "humidity": 78,
#         "pressure": 1014,
#         "temp": 300.56,
#         "temp_max": 303.14,
#         "temp_min": 297.6
#     },
#     "name": "Melbourne",
#     "sys": {
#         "country": "US",
#         "id": 2007578,
#         "sunrise": 1689935912,
#         "sunset": 1689985125,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 5.14
#     }
# }
# 28.0836
# -80.6081
# 303.14
# 78
# 0
# 5.14
# US

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
main_url = "http://api.openweathermap.org/data/2.5/weather?"
#declaring units as metrics
units = "metric"
#url
url = f"{main_url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
today = datetime.today().strftime('%d-%m-%Y')

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    response = requests.get(city_url)
    #print(json.dumps(response_json, indent=4, sort_keys=True))
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #print(json.dumps(city_weather, indent=4, sort_keys=True))

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        #print(city_lat)
        city_lng = city_weather["coord"]["lon"]
        #print(city_lng)
        city_max_temp = city_weather["main"]["temp_max"]
        #print(city_max_temp)
        city_humidity = city_weather["main"]["humidity"]
        #print (city_humidity)
        city_clouds = city_weather["clouds"]["all"]
        #print(city_clouds)
        city_wind = city_weather["wind"]["speed"]
        #print(city_wind)
        city_country = city_weather["sys"]["country"]
        #print(city_country)
        city_date = today

        #Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kununurra
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | anibare
# City not found. Skipping...
# Processing Record 6 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | estancia
# Processing Record 10 of Set 1 | mermoz boabab
# Processing Record 11 of Set 1 | pisco
# Processing Record 12 of Set 1 | kavaratti
# Processing Record 13 of Set 1 | saipan
# Processing Record 14 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 1 | temiskaming shores
# Processing Record 16 of Set 1 | fale old settlement
# Processing Record 17 of Set 1 | whitehorse
# Processing Record 18 of Set 1 | badger
# Processing Record 19 of Set 1 | edinburgh of the seven seas
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | willemstad
# Processing Record 22 of Set 1 | san antonio de pale
# Processing Record 23 of Set 1 | margaret river
# Processing Record 24 of Set 1 | udachny
# Processing Record 25 of Set 1 | malango
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | prince george
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | sitka
# Processing Record 30 of Set 1 | shimoda
# Processing Record 31 of Set 1 | nar'yan-mar
# Processing Record 32 of Set 1 | blackmans bay
# Processing Record 33 of Set 1 | kupang
# Processing Record 34 of Set 1 | santa cruz
# Processing Record 35 of Set 1 | ha'il
# Processing Record 36 of Set 1 | sarykemer
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | ardakan
# Processing Record 39 of Set 1 | waitangi
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | vadso
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | papatowai
# Processing Record 44 of Set 1 | zag
# Processing Record 45 of Set 1 | naze
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | alice springs
# Processing Record 48 of Set 1 | remire-montjoly
# Processing Record 49 of Set 1 | aladag
# Processing Record 50 of Set 1 | puerto natales
# Processing Record 0 of Set 2 | mukalla
# Processing Record 1 of Set 2 | brady
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | salaga
# Processing Record 4 of Set 2 | enewetak
# Processing Record 5 of Set 2 | salinas
# Processing Record 6 of Set 2 | manggar
# Processing Record 7 of Set 2 | abagur
# Processing Record 8 of Set 2 | olonkinbyen
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | kawthoung
# City not found. Skipping...
# Processing Record 11 of Set 2 | stanley
# Processing Record 12 of Set 2 | grytviken
# Processing Record 13 of Set 2 | punch
# Processing Record 14 of Set 2 | sandnessjoen
# Processing Record 15 of Set 2 | tarnogskiy gorodok
# Processing Record 16 of Set 2 | kerema
# Processing Record 17 of Set 2 | tralee
# Processing Record 18 of Set 2 | utrik
# Processing Record 19 of Set 2 | broken hill
# Processing Record 20 of Set 2 | novokazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 2 | west island
# Processing Record 22 of Set 2 | anadyr
# Processing Record 23 of Set 2 | lovisa
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | champua
# Processing Record 26 of Set 2 | santa elena de uairen
# Processing Record 27 of Set 2 | smithers
# Processing Record 28 of Set 2 | fraserburgh
# Processing Record 29 of Set 2 | nicoya
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | urangan
# Processing Record 32 of Set 2 | slavyanka
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | mhamid
# Processing Record 35 of Set 2 | podborany
# Processing Record 36 of Set 2 | kangding
# Processing Record 37 of Set 2 | dwarka
# Processing Record 38 of Set 2 | alesund
# Processing Record 39 of Set 2 | san luis de la loma
# Processing Record 40 of Set 2 | kongsvinger
# Processing Record 41 of Set 2 | victoriaville
# Processing Record 42 of Set 2 | namibe
# Processing Record 43 of Set 2 | sisimiut
# Processing Record 44 of Set 2 | ati
# Processing Record 45 of Set 2 | ust-nera
# Processing Record 46 of Set 2 | meinersen
# Processing Record 47 of Set 2 | fort wellington
# Processing Record 48 of Set 2 | knyaze-volkonskoye
# Processing Record 49 of Set 2 | ishigaki
# Processing Record 0 of Set 3 | praia da vitoria
# Processing Record 1 of Set 3 | mabaruma
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | rurrenabaque
# Processing Record 4 of Set 3 | alakurtti
# Processing Record 5 of Set 3 | kismayo
# Processing Record 6 of Set 3 | cimarron hills
# Processing Record 7 of Set 3 | cooma
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | guiuan
# Processing Record 11 of Set 3 | grand gaube
# Processing Record 12 of Set 3 | costa calma
# City not found. Skipping...
# Processing Record 13 of Set 3 | wailua homesteads
# Processing Record 14 of Set 3 | nikolayevsk-on-amure
# Processing Record 15 of Set 3 | pavilosta
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | bubaque
# Processing Record 18 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 19 of Set 3 | saratamata
# City not found. Skipping...
# Processing Record 20 of Set 3 | moissala
# Processing Record 21 of Set 3 | codrington
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | matehuala
# Processing Record 24 of Set 3 | ivdel'
# Processing Record 25 of Set 3 | isafjordur
# Processing Record 26 of Set 3 | qal'at bishah
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | lihue
# Processing Record 29 of Set 3 | idri
# Processing Record 30 of Set 3 | ola
# Processing Record 31 of Set 3 | araguaina
# Processing Record 32 of Set 3 | enchanted hills
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | dogubayazit
# Processing Record 35 of Set 3 | klimovo
# Processing Record 36 of Set 3 | guiratinga
# Processing Record 37 of Set 3 | barranca
# Processing Record 38 of Set 3 | neuried
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 3 | st. john's
# Processing Record 42 of Set 3 | holualoa
# Processing Record 43 of Set 3 | tanjung pandan
# Processing Record 44 of Set 3 | klyuchi
# Processing Record 45 of Set 3 | thinadhoo
# Processing Record 46 of Set 3 | zhalantun
# Processing Record 47 of Set 3 | vorgashor
# Processing Record 48 of Set 3 | brokopondo
# Processing Record 49 of Set 3 | floro
# Processing Record 0 of Set 4 | madalena
# Processing Record 1 of Set 4 | north bend
# Processing Record 2 of Set 4 | argo
# Processing Record 3 of Set 4 | el granada
# Processing Record 4 of Set 4 | kindia
# Processing Record 5 of Set 4 | qingdao
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | port saint john's
# Processing Record 8 of Set 4 | chonchi
# Processing Record 9 of Set 4 | nadym
# Processing Record 10 of Set 4 | gulf shores
# Processing Record 11 of Set 4 | mao
# Processing Record 12 of Set 4 | bilibino
# Processing Record 13 of Set 4 | constantia
# Processing Record 14 of Set 4 | ilhabela
# Processing Record 15 of Set 4 | uturoa
# Processing Record 16 of Set 4 | muynoq
# Processing Record 17 of Set 4 | kerikeri
# Processing Record 18 of Set 4 | khorixas
# Processing Record 19 of Set 4 | ordos
# City not found. Skipping...
# Processing Record 20 of Set 4 | gueltat zemmour
# City not found. Skipping...
# Processing Record 21 of Set 4 | margate
# Processing Record 22 of Set 4 | awash
# Processing Record 23 of Set 4 | hasaki
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | invercargill
# Processing Record 27 of Set 4 | mont-de-marsan
# Processing Record 28 of Set 4 | yemva
# Processing Record 29 of Set 4 | bainbridge
# Processing Record 30 of Set 4 | nakonde
# Processing Record 31 of Set 4 | karakoyunlu
# Processing Record 32 of Set 4 | halifax
# Processing Record 33 of Set 4 | laguna
# Processing Record 34 of Set 4 | san jose
# Processing Record 35 of Set 4 | kitimat
# Processing Record 36 of Set 4 | ciudad lazaro cardenas
# Processing Record 37 of Set 4 | savonlinna
# Processing Record 38 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 39 of Set 4 | wodonga
# Processing Record 40 of Set 4 | mahina
# Processing Record 41 of Set 4 | dobryanka
# Processing Record 42 of Set 4 | aasiaat
# Processing Record 43 of Set 4 | cabo san lucas
# Processing Record 44 of Set 4 | gilleleje
# Processing Record 45 of Set 4 | country club
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | guatrache
# Processing Record 48 of Set 4 | mount pearl
# Processing Record 49 of Set 4 | ancud
# Processing Record 0 of Set 5 | siguiri
# Processing Record 1 of Set 5 | marudi
# City not found. Skipping...
# Processing Record 2 of Set 5 | funafuti
# Processing Record 3 of Set 5 | happy valley-goose bay
# Processing Record 4 of Set 5 | kalianget
# Processing Record 5 of Set 5 | taro
# Processing Record 6 of Set 5 | howard springs
# Processing Record 7 of Set 5 | dawesville
# Processing Record 8 of Set 5 | hawaiian paradise park
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 11 of Set 5 | machico
# Processing Record 12 of Set 5 | muisne
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | turochak
# Processing Record 15 of Set 5 | doha
# Processing Record 16 of Set 5 | boa vista
# Processing Record 17 of Set 5 | mocoreta
# Processing Record 18 of Set 5 | iskateley
# Processing Record 19 of Set 5 | faya-largeau
# Processing Record 20 of Set 5 | dabakala
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | aden
# Processing Record 23 of Set 5 | villa maria grande
# Processing Record 24 of Set 5 | minas de marcona
# Processing Record 25 of Set 5 | saint-georges
# Processing Record 26 of Set 5 | midvagur
# Processing Record 27 of Set 5 | dukhan
# Processing Record 28 of Set 5 | polyarnyye zori
# Processing Record 29 of Set 5 | selfoss
# Processing Record 30 of Set 5 | igarka
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | tazovsky
# Processing Record 33 of Set 5 | birobidzhan
# Processing Record 34 of Set 5 | parauna
# Processing Record 35 of Set 5 | harindanga
# Processing Record 36 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 37 of Set 5 | labytnangi
# Processing Record 38 of Set 5 | senador pompeu
# Processing Record 39 of Set 5 | am djarass
# City not found. Skipping...
# Processing Record 40 of Set 5 | atafu village
# Processing Record 41 of Set 5 | arteche
# Processing Record 42 of Set 5 | coahuayana de hidalgo
# Processing Record 43 of Set 5 | herceg novi
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | loa janan
# Processing Record 46 of Set 5 | bandarbeyla
# Processing Record 47 of Set 5 | chibougamau
# Processing Record 48 of Set 5 | polyarnyy
# Processing Record 49 of Set 5 | cockburn town
# Processing Record 0 of Set 6 | arish
# Processing Record 1 of Set 6 | mangrol
# Processing Record 2 of Set 6 | dudinka
# Processing Record 3 of Set 6 | phillip island
# Processing Record 4 of Set 6 | ramnagar
# Processing Record 5 of Set 6 | yurimaguas
# Processing Record 6 of Set 6 | burwell
# Processing Record 7 of Set 6 | ennis
# Processing Record 8 of Set 6 | palmer
# Processing Record 9 of Set 6 | kencong
# Processing Record 10 of Set 6 | vallenar
# Processing Record 11 of Set 6 | tsiombe
# Processing Record 12 of Set 6 | nuku'alofa
# Processing Record 13 of Set 6 | qamdo
# Processing Record 14 of Set 6 | ridgecrest
# Processing Record 15 of Set 6 | pskov
# Processing Record 16 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 6 | tangalle
# Processing Record 18 of Set 6 | bakchar
# Processing Record 19 of Set 6 | pali
# Processing Record 20 of Set 6 | puerto deseado
# Processing Record 21 of Set 6 | yuzhno-kurilsk
# Processing Record 22 of Set 6 | punta arenas
# Processing Record 23 of Set 6 | nabire
# Processing Record 24 of Set 6 | ghat
# Processing Record 25 of Set 6 | sarikei
# Processing Record 26 of Set 6 | vanimo
# Processing Record 27 of Set 6 | mariehamn
# Processing Record 28 of Set 6 | whakatane
# Processing Record 29 of Set 6 | lorengau
# Processing Record 30 of Set 6 | juneau
# Processing Record 31 of Set 6 | boguchany
# Processing Record 32 of Set 6 | kone
# Processing Record 33 of Set 6 | port mathurin
# Processing Record 34 of Set 6 | corner brook
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | cascais
# Processing Record 37 of Set 6 | kalinkavichy
# Processing Record 38 of Set 6 | kirakira
# Processing Record 39 of Set 6 | alenquer
# Processing Record 40 of Set 6 | antofagasta
# Processing Record 41 of Set 6 | keflavik
# Processing Record 42 of Set 6 | chamzinka
# Processing Record 43 of Set 6 | freetown
# Processing Record 44 of Set 6 | novaya igirma
# Processing Record 45 of Set 6 | qashyr
# Processing Record 46 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 47 of Set 6 | pauini
# Processing Record 48 of Set 6 | barreirinhas
# Processing Record 49 of Set 6 | mount gambier
# Processing Record 0 of Set 7 | cill airne
# Processing Record 1 of Set 7 | hasanpur
# Processing Record 2 of Set 7 | villa gesell
# Processing Record 3 of Set 7 | nikko
# Processing Record 4 of Set 7 | san nicolas guadalupe
# Processing Record 5 of Set 7 | ambovombe
# Processing Record 6 of Set 7 | udomlya
# Processing Record 7 of Set 7 | totness
# Processing Record 8 of Set 7 | hadibu
# Processing Record 9 of Set 7 | ar rutbah
# Processing Record 10 of Set 7 | ulladulla
# Processing Record 11 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 12 of Set 7 | port alfred
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | kozan
# Processing Record 15 of Set 7 | grand falls-windsor
# Processing Record 16 of Set 7 | namdrik
# Processing Record 17 of Set 7 | mersa matruh
# Processing Record 18 of Set 7 | raja
# Processing Record 19 of Set 7 | saint-philippe
# Processing Record 20 of Set 7 | asheboro
# Processing Record 21 of Set 7 | glace bay
# Processing Record 22 of Set 7 | prince rupert
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | aginskoye
# Processing Record 25 of Set 7 | island harbour
# Processing Record 26 of Set 7 | aykhal
# Processing Record 27 of Set 7 | loiza
# Processing Record 28 of Set 7 | guerrero negro
# Processing Record 29 of Set 7 | hilo
# Processing Record 30 of Set 7 | huanan
# Processing Record 31 of Set 7 | balabac
# Processing Record 32 of Set 7 | la ronge
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | porto novo
# Processing Record 35 of Set 7 | popesti
# Processing Record 36 of Set 7 | bathsheba
# Processing Record 37 of Set 7 | hamilton
# Processing Record 38 of Set 7 | samarinda
# Processing Record 39 of Set 7 | hurricane
# Processing Record 40 of Set 7 | moyale
# Processing Record 41 of Set 7 | cambria
# Processing Record 42 of Set 7 | rainham
# Processing Record 43 of Set 7 | tympaki
# Processing Record 44 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 7 | hope
# Processing Record 46 of Set 7 | hammerfest
# Processing Record 47 of Set 7 | launceston
# Processing Record 48 of Set 7 | floriano
# Processing Record 49 of Set 7 | zhaqsy
# Processing Record 0 of Set 8 | daru
# Processing Record 1 of Set 8 | qaqortoq
# Processing Record 2 of Set 8 | torrington
# Processing Record 3 of Set 8 | khao yoi
# Processing Record 4 of Set 8 | 'ain benian
# Processing Record 5 of Set 8 | zaragoza
# Processing Record 6 of Set 8 | umm kaddadah
# Processing Record 7 of Set 8 | viedma
# Processing Record 8 of Set 8 | kruisfontein
# Processing Record 9 of Set 8 | kirkwall
# Processing Record 10 of Set 8 | wotje
# Processing Record 11 of Set 8 | oneonta
# Processing Record 12 of Set 8 | salmon arm
# Processing Record 13 of Set 8 | hargeysa
# Processing Record 14 of Set 8 | bam
# Processing Record 15 of Set 8 | notse
# Processing Record 16 of Set 8 | san julian
# Processing Record 17 of Set 8 | jinxiang
# Processing Record 18 of Set 8 | tweed heads
# Processing Record 19 of Set 8 | khandyga
# Processing Record 20 of Set 8 | qiziltepa
# Processing Record 21 of Set 8 | gasa
# Processing Record 22 of Set 8 | la maddalena
# Processing Record 23 of Set 8 | bel ombre
# Processing Record 24 of Set 8 | aljezur
# Processing Record 25 of Set 8 | kharovsk
# Processing Record 26 of Set 8 | sao joao da barra
# Processing Record 27 of Set 8 | guiyang
# Processing Record 28 of Set 8 | san pedro
# Processing Record 29 of Set 8 | la passe
# Processing Record 30 of Set 8 | pitimbu
# Processing Record 31 of Set 8 | quellon
# Processing Record 32 of Set 8 | ebaye
# Processing Record 33 of Set 8 | callao
# Processing Record 34 of Set 8 | harper
# Processing Record 35 of Set 8 | altay
# Processing Record 36 of Set 8 | san pedro de alcantara
# Processing Record 37 of Set 8 | lautoka
# Processing Record 38 of Set 8 | brasilia de minas
# Processing Record 39 of Set 8 | banaz
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | carnarvon
# Processing Record 42 of Set 8 | saudarkrokur
# Processing Record 43 of Set 8 | vilyuchinsk
# Processing Record 44 of Set 8 | dellys
# Processing Record 45 of Set 8 | sanctuary point
# Processing Record 46 of Set 8 | pierre
# Processing Record 47 of Set 8 | moyynkum
# Processing Record 48 of Set 8 | mapimi
# Processing Record 49 of Set 8 | dalai
# Processing Record 0 of Set 9 | titay
# Processing Record 1 of Set 9 | muravlenko
# Processing Record 2 of Set 9 | kapuskasing
# Processing Record 3 of Set 9 | mili
# Processing Record 4 of Set 9 | xiongzhou
# Processing Record 5 of Set 9 | berdigestyakh
# Processing Record 6 of Set 9 | saint-joseph
# Processing Record 7 of Set 9 | rongelap
# Processing Record 8 of Set 9 | afaahiti
# Processing Record 9 of Set 9 | egilsstadir
# Processing Record 10 of Set 9 | dzerzhinskoye
# Processing Record 11 of Set 9 | christchurch
# Processing Record 12 of Set 9 | juliaca
# Processing Record 13 of Set 9 | luganville
# Processing Record 14 of Set 9 | sant'antioco
# Processing Record 15 of Set 9 | west greenwich
# Processing Record 16 of Set 9 | east london
# Processing Record 17 of Set 9 | atamyrat
# Processing Record 18 of Set 9 | ibra'
# City not found. Skipping...
# Processing Record 19 of Set 9 | kristiansund
# Processing Record 20 of Set 9 | greenville
# Processing Record 21 of Set 9 | ebon
# Processing Record 22 of Set 9 | at taj
# Processing Record 23 of Set 9 | bridgetown
# Processing Record 24 of Set 9 | kralendijk
# Processing Record 25 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 9 | castro de rei
# Processing Record 27 of Set 9 | reuleuet
# Processing Record 28 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 29 of Set 9 | shenjiamen
# Processing Record 30 of Set 9 | quirihue
# Processing Record 31 of Set 9 | zharkent
# Processing Record 32 of Set 9 | alindao
# Processing Record 33 of Set 9 | jian'ou
# Processing Record 34 of Set 9 | zhezqazghan
# Processing Record 35 of Set 9 | palmwoods
# Processing Record 36 of Set 9 | lagoa
# Processing Record 37 of Set 9 | hecun
# Processing Record 38 of Set 9 | havre
# Processing Record 39 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 40 of Set 9 | napanee
# Processing Record 41 of Set 9 | biloela
# Processing Record 42 of Set 9 | nyurba
# Processing Record 43 of Set 9 | riachao
# Processing Record 44 of Set 9 | kapa'a
# Processing Record 45 of Set 9 | weno
# Processing Record 46 of Set 9 | port douglas
# Processing Record 47 of Set 9 | susuman
# Processing Record 48 of Set 9 | victoria
# Processing Record 49 of Set 9 | mil'kovo
# Processing Record 0 of Set 10 | xinyuan
# Processing Record 1 of Set 10 | greymouth
# Processing Record 2 of Set 10 | nemuro
# Processing Record 3 of Set 10 | onguday
# Processing Record 4 of Set 10 | sokoni
# Processing Record 5 of Set 10 | mimizan
# Processing Record 6 of Set 10 | techiman
# Processing Record 7 of Set 10 | inarajan village
# Processing Record 8 of Set 10 | thunder bay
# Processing Record 9 of Set 10 | fort mcmurray
# Processing Record 10 of Set 10 | howrah
# Processing Record 11 of Set 10 | bintulu
# Processing Record 12 of Set 10 | kailua-kona
# Processing Record 13 of Set 10 | maragogi
# Processing Record 14 of Set 10 | gadzhiyevo
# Processing Record 15 of Set 10 | singojuruh
# Processing Record 16 of Set 10 | ouani
# Processing Record 17 of Set 10 | carnot
# Processing Record 18 of Set 10 | turkmenbasy
# Processing Record 19 of Set 10 | gazli
# Processing Record 20 of Set 10 | kenai
# Processing Record 21 of Set 10 | fort bragg
# Processing Record 22 of Set 10 | lingyuan
# Processing Record 23 of Set 10 | nuuk
# Processing Record 24 of Set 10 | pitkyaranta
# Processing Record 25 of Set 10 | el-tor
# Processing Record 26 of Set 10 | caleta de carquin
# Processing Record 27 of Set 10 | xi'an
# Processing Record 28 of Set 10 | sofifi
# City not found. Skipping...
# Processing Record 29 of Set 10 | san rafael del sur
# Processing Record 30 of Set 10 | road town
# Processing Record 31 of Set 10 | coromandel
# Processing Record 32 of Set 10 | nova sintra
# Processing Record 33 of Set 10 | flying fish cove
# Processing Record 34 of Set 10 | sharkawshchyna
# Processing Record 35 of Set 10 | touros
# Processing Record 36 of Set 10 | bayanhongor
# Processing Record 37 of Set 10 | qingnian
# Processing Record 38 of Set 10 | buka
# Processing Record 39 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 40 of Set 10 | oak bay
# Processing Record 41 of Set 10 | at taraf
# Processing Record 42 of Set 10 | bourbonnais
# Processing Record 43 of Set 10 | yauco
# Processing Record 44 of Set 10 | kukes
# Processing Record 45 of Set 10 | queenstown
# Processing Record 46 of Set 10 | charlottetown
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | sittwe
# Processing Record 49 of Set 10 | korla
# Processing Record 0 of Set 11 | la sarre
# Processing Record 1 of Set 11 | alofi
# Processing Record 2 of Set 11 | kaedi
# Processing Record 3 of Set 11 | ginir
# Processing Record 4 of Set 11 | el gouna
# Processing Record 5 of Set 11 | al jawf
# Processing Record 6 of Set 11 | chui
# Processing Record 7 of Set 11 | mol
# Processing Record 8 of Set 11 | maceio
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | crane
# Processing Record 11 of Set 11 | beterou
# Processing Record 12 of Set 11 | mariental
# Processing Record 13 of Set 11 | sterling
# Processing Record 14 of Set 11 | tula de allende
# Processing Record 15 of Set 11 | bargaal
# Processing Record 16 of Set 11 | olyokminsk
# Processing Record 17 of Set 11 | kuragino
# Processing Record 18 of Set 11 | kill devil hills
# Processing Record 19 of Set 11 | gorgan
# Processing Record 20 of Set 11 | sao vicente
# Processing Record 21 of Set 11 | nueva esperanza
# Processing Record 22 of Set 11 | qui nhon
# Processing Record 23 of Set 11 | ichalkaranji
# Processing Record 24 of Set 11 | shimanovsk
# Processing Record 25 of Set 11 | gaspe
# Processing Record 26 of Set 11 | nova vicosa
# Processing Record 27 of Set 11 | jeddah
# Processing Record 28 of Set 11 | sinop
# Processing Record 29 of Set 11 | ad dawadimi
# Processing Record 30 of Set 11 | al kharijah
# Processing Record 31 of Set 11 | korotchaevo
# City not found. Skipping...
# Processing Record 32 of Set 11 | ghadamis
# Processing Record 33 of Set 11 | dolores
# Processing Record 34 of Set 11 | lycksele
# Processing Record 35 of Set 11 | villanueva
# Processing Record 36 of Set 11 | tarko-sale
# Processing Record 37 of Set 11 | tolanaro
# Processing Record 38 of Set 11 | usinsk
# Processing Record 39 of Set 11 | maintirano
# Processing Record 40 of Set 11 | sarukhan
# Processing Record 41 of Set 11 | manokwari
# Processing Record 42 of Set 11 | tvoroyri
# Processing Record 43 of Set 11 | pampa del infierno
# Processing Record 44 of Set 11 | den burg
# Processing Record 45 of Set 11 | riberalta
# Processing Record 46 of Set 11 | santo antonio do ica
# Processing Record 47 of Set 11 | bardai
# Processing Record 48 of Set 11 | puerto armuelles
# Processing Record 49 of Set 11 | kashary
# Processing Record 0 of Set 12 | menongue
# Processing Record 1 of Set 12 | mwanza
# Processing Record 2 of Set 12 | ocean city
# Processing Record 3 of Set 12 | berezovo
# Processing Record 4 of Set 12 | sydney mines
# Processing Record 5 of Set 12 | necochea
# Processing Record 6 of Set 12 | vilhena
# Processing Record 7 of Set 12 | bossangoa
# Processing Record 8 of Set 12 | mar del plata
# Processing Record 9 of Set 12 | kuanda
# Processing Record 10 of Set 12 | bereket
# Processing Record 11 of Set 12 | epanomi
# Processing Record 12 of Set 12 | yevpatoriya
# Processing Record 13 of Set 12 | robertsport
# Processing Record 14 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 15 of Set 12 | nalut
# Processing Record 16 of Set 12 | mata-utu
# Processing Record 17 of Set 12 | myitkyina
# Processing Record 18 of Set 12 | umm as sahik
# Processing Record 19 of Set 12 | prince albert
# Processing Record 20 of Set 12 | vilyuysk
# Processing Record 21 of Set 12 | laiwu
# Processing Record 22 of Set 12 | upington
# Processing Record 23 of Set 12 | gaigeturi
# Processing Record 24 of Set 12 | shevchenko
# Processing Record 25 of Set 12 | chake chake
# Processing Record 26 of Set 12 | el calafate
# Processing Record 27 of Set 12 | imeni morozova
# Processing Record 28 of Set 12 | qurayyat
# Processing Record 29 of Set 12 | musay'id
# City not found. Skipping...
# Processing Record 30 of Set 12 | dauphin
# Processing Record 31 of Set 12 | tidjikja
# Processing Record 32 of Set 12 | isiro
# Processing Record 33 of Set 12 | kaka
# Processing Record 34 of Set 12 | arkalyk
# Processing Record 35 of Set 12 | xilin hot
# Processing Record 36 of Set 12 | madang
# Processing Record 37 of Set 12 | camana
# Processing Record 38 of Set 12 | huanren
# Processing Record 39 of Set 12 | isla mujeres
# Processing Record 40 of Set 12 | rio grande
# Processing Record 41 of Set 12 | muromtsevo
# Processing Record 42 of Set 12 | vel'sk
# Processing Record 43 of Set 12 | otterndorf
# Processing Record 44 of Set 12 | chacarita
# Processing Record 45 of Set 12 | wotho
# Processing Record 46 of Set 12 | ayr
# Processing Record 47 of Set 12 | krasnobrodskiy
# Processing Record 48 of Set 12 | san lucas ojitlan
# Processing Record 49 of Set 12 | piquete
# Processing Record 0 of Set 13 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 13 | salahonda
# Processing Record 2 of Set 13 | dampit
# Processing Record 3 of Set 13 | champerico
# Processing Record 4 of Set 13 | penzance
# Processing Record 5 of Set 13 | nadi
# Processing Record 6 of Set 13 | long beach
# Processing Record 7 of Set 13 | sinabang
# Processing Record 8 of Set 13 | kayangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#print(city_data)
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame (city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                 kununurra -15.7667  128.7333     28.99        26
# 1         port-aux-francais -49.3500   70.2167      1.21        88
# 2                    albany  42.6001  -73.9662     19.24        92
# 3                 adamstown -25.0660 -130.1015     21.00        71
# 4  petropavlovsk-kamchatsky  53.0452  158.6483     22.33        60
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        7.20      AU  22-07-2023
# 1         100        5.80      TF  22-07-2023
# 2           0        2.89      US  22-07-2023
# 3          14       13.44      PN  22-07-2023
# 4          75        4.00      RU  22-07-2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       kununurra -15.7667  128.7333     28.99        26
# 1               port-aux-francais -49.3500   70.2167      1.21        88
# 2                          albany  42.6001  -73.9662     19.24        92
# 3                       adamstown -25.0660 -130.1015     21.00        71
# 4        petropavlovsk-kamchatsky  53.0452  158.6483     22.33        60
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        7.20      AU  22-07-2023
# 1               100        5.80      TF  22-07-2023
# 2                 0        2.89      US  22-07-2023
# 3                14       13.44      PN  22-07-2023
# 4                75        4.00      RU  22-07-2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()


# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Wind Speed m/s')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] > 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                          albany  42.6001  -73.9662     19.24        92
# 4        petropavlovsk-kamchatsky  53.0452  158.6483     22.33        60
# 6                          bethel  41.3712  -73.4140     22.17        81
# 8                   mermoz boabab  14.7065  -17.4758     27.88        78
# 10                      kavaratti  10.5669   72.6420     28.18        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                 0        2.89      US  22-07-2023
# 4                75        4.00      RU  22-07-2023
# 6                 0        0.00      US  22-07-2023
# 8                40        4.12      SN  22-07-2023
# 10               85        9.12      IN  22-07-2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                kununurra -15.7667  128.7333     28.99        26           0
# 1        port-aux-francais -49.3500   70.2167      1.21        88         100
# 3                adamstown -25.0660 -130.1015     21.00        71          14
# 5                     lebu -37.6167  -73.6500     10.14        89         100
# 7                 estancia -11.2683  -37.4383     20.73        87           6
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      AU  22-07-2023
# 1              5.80      TF  22-07-2023
# 3             13.44      PN  22-07-2023
# 5              4.02      CL  22-07-2023
# 7              2.03      BR  22-07-2023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()
print(line_eq)
print(f"The correlation between Max Temp and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.21x + 30.65
# The correlation between Max Temp and Latitude is: 0.33801

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-40,-5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()
print(line_eq)
print(f"The correlation between between Max Temp and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = 0.44x + 28.54
# The correlation between between Max Temp and Latitude is: 0.6582

# %% [markdown]
# **Discussion about the linear relationship:**
#     In General Max Temp decreases as the latitude moves away from the equator
#     The correlation for Max temp vs latitude in the southern hemisphere is stronger than the same for the northern hemisphere
#     by roughly a factor of 2. Both correlation coafficients, however, are not strong to conclude a good relationship.
#     The temp range covered in north (0 to 50) is wider than in the rnage coverd in south (-5 to 35)
#     The scatter around the strightline in both cases is wide. The scatter around the straighline in the north is more than in the south. There other factors, such as elevation above mean sea level, that control Temp.
#     Liner relationship does not reflect the relationship between Max Temp and Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(47,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Humidity and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.08x + 73.46
# The correlation between Humidity and Latitude is: 0.00456

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Humidity and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.16x + 66.77
# The correlation between Humidity and Latitude is: 0.01693

# %% [markdown]
# **Discussion about the linear relationship:
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Humidity and Latitude in both region when using straighlines.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(47,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Cloudiness and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = 0.05x + 56.18
# The correlation between Cloudiness and Latitude is: 0.00055

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-50,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(line_eq)
print(f"The correlation between Cloudiness and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.69x + 36.46
# The correlation between Cloudiness and Latitude is: 0.06418

# %% [markdown]
# **Discussion about the linear relationship:**
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Cloudiness and Latitude in both region when using straighlines.
#     Again, other factors should be considerd to determin a relationship between Cloudiness and Latitude.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(50,11),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
print(line_eq)
print(f"The correlation between Wind Speed and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.02x + 4.08
# The correlation between Wind Speed and Latitude is: 0.01394

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-30,13),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
print(line_eq)
print(f"The correlation between Wind Speed and Latitude is: {round(rvalue**2, 5)}")
plt.show()
# Out:
# y = -0.01x + 3.78
# The correlation between Wind Speed and Latitude is: 0.0025

# %% [markdown]
# **Discussion about the linear relationship:**
#     Too much visable scatter around straightline for both northern and southern hemisphere
#     extermely week correlation coefficient in both regions,
#     it is safe to say that there is no relationship between Wind Speed and Latitude in both region when using straighlines.
#     Looking at the graphs, I do not think it is possible to find a relationship using traditional liner or non-liner regression.
#     This is a good candidate for a Neural Network study.
